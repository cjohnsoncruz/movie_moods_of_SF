# %% [markdown]
# # Can you quantify the culture of a city?
# ## Studying the many moods of San Francisco through movies, using Python, Pandas, and Plotly:
#
#
# *“Cities, like dreams, are made of desires and fears, even if the thread of their discourse is secret, their rules are absurd, their perspectives deceitful, and everything conceals something else.”*
# ― Italo Calvino, Invisible Cities
#
# In this notebook I hope to reveal some of the threads of San Francisco's outline, as used for dramatic effect in films. The city government of San Francisco keeps records, going back nearly to the dawn of film, of all the locations of the city that have been featured on celluloid. The data is messy, so I perform data cleaning and pre-processing before mapping the data and examining its structure.
#
# Can we quantify the "mood" of a neighborhood based on the kinds of movies that have used it for locations? We will find out!
# Special thanks to the city of San Francisco for making these records readily available!

# %%
#import libraries
import pandas as pd
import numpy as np
import scipy as sc
import requests
import io
import gzip

# !pip install geopandas greppo sodapy bs4 thefuzz[speedup] cinemagoer

from imdb import Cinemagoer

from thefuzz import fuzz, process #https://github.com/seatgeek/thefuzz, updated version of fuzzy wuzzy
from bs4 import BeautifulSoup
from re import search
import geopandas
import greppo
import sodapy
from sodapy import Socrata

import seaborn as sns
import matplotlib.pyplot as plt
from pprint import pprint

import tqdm
import datetime as dt
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 14.3 MB/s
# Collecting greppo
#   Downloading greppo-0.0.25-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 54.9 MB/s
# Collecting sodapy
#   Downloading sodapy-2.1.1-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Collecting thefuzz[speedup]
#   Downloading thefuzz-0.19.0-py2.py3-none-any.whl (17 kB)
# Collecting cinemagoer
#   Downloading cinemagoer-2022.2.11-py3-none-any.whl (301 kB)
#      |████████████████████████████████| 301 kB 64.7 MB/s
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.3.5)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.21-cp37-cp37m-manylinux2014_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 419 kB/s
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 37.1 MB/s
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.2)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2022.5.18.1)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (21.4.0)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.21.6)
# Requirement already satisfied: earthengine-api in /usr/local/lib/python3.7/dist-packages (from greppo) (0.1.311)
# Collecting xyzservices
#   Downloading xyzservices-2022.4.0-py3-none-any.whl (36 kB)
# Collecting click>=4.0
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 4.8 MB/s
# Collecting uvicorn==0.15.0
#   Downloading uvicorn-0.15.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.1 MB/s
# Collecting rasterio==1.2.10
#   Downloading rasterio-1.2.10-cp37-cp37m-manylinux1_x86_64.whl (19.3 MB)
#      |████████████████████████████████| 19.3 MB 1.3 MB/s
# Collecting Pillow==8.4.0
#   Downloading Pillow-8.4.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 65.9 MB/s
# Collecting starlette==0.16.0
#   Downloading starlette-0.16.0-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 290 kB/s
# Collecting shapely>=1.6
#   Downloading Shapely-1.7.1-cp37-cp37m-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 41.8 MB/s
# Collecting meta==1.0.2
#   Downloading meta-1.0.2.tar.gz (49 kB)
#      |████████████████████████████████| 49 kB 5.1 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from click>=4.0->fiona>=1.8->geopandas) (4.11.4)
# Collecting affine
#   Downloading affine-2.3.1-py2.py3-none-any.whl (16 kB)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from starlette==0.16.0->greppo) (4.2.0)
# Collecting anyio<4,>=3.0.0
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 10.4 MB/s
# Collecting asgiref>=3.4.0
#   Downloading asgiref-3.5.2-py3-none-any.whl (22 kB)
# Collecting h11>=0.8
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.3 MB/s
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.0.0->starlette==0.16.0->greppo) (2.10)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.7/dist-packages (from snuggs>=1.4.1->rasterio==1.2.10->greppo) (3.0.9)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from sodapy) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->sodapy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->sodapy) (1.24.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4) (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from cinemagoer) (4.2.6)
# Requirement already satisfied: SQLAlchemy in /usr/local/lib/python3.7/dist-packages (from cinemagoer) (1.4.36)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from earthengine-api->greppo) (1.35.0)
# Requirement already satisfied: httplib2shim in /usr/local/lib/python3.7/dist-packages (from earthengine-api->greppo) (0.0.3)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in /usr/local/lib/python3.7/dist-packages (from earthengine-api->greppo) (1.12.11)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from earthengine-api->greppo) (0.0.4)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from earthengine-api->greppo) (0.17.4)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from earthengine-api->greppo) (0.16.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.7/dist-packages (from earthengine-api->greppo) (1.18.1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.12.1->earthengine-api->greppo) (3.0.1)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client<2,>=1.12.1->earthengine-api->greppo) (1.31.6)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api->greppo) (21.3)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api->greppo) (3.17.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api->greppo) (1.56.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->earthengine-api->greppo) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->earthengine-api->greppo) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.4.1->earthengine-api->greppo) (0.2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api->greppo) (0.4.8)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->earthengine-api->greppo) (1.0.3)
# Requirement already satisfied: google-resumable-media<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->earthengine-api->greppo) (0.4.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->click>=4.0->fiona>=1.8->geopandas) (3.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy->cinemagoer) (1.1.2)
# Collecting python-levenshtein>=0.12
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 7.9 MB/s
# Building wheels for collected packages: meta, python-levenshtein
#   Building wheel for meta (setup.py) ... done
#   Created wheel for meta: filename=meta-1.0.2-py3-none-any.whl size=59240 sha256=ec44da1dfff73dc4a11dea1525baaf87fc9ac8271c022e0e47892220d4f79a01
#   Stored in directory: /root/.cache/pip/wheels/e0/02/ab/cad231f511187a723a91797702e12224c5ea1cbe3425e487bb
#   Building wheel for python-levenshtein (setup.py) ... done
#   Created wheel for python-levenshtein: filename=python_Levenshtein-0.12.2-cp37-cp37m-linux_x86_64.whl size=149873 sha256=7c07c6516dba6fd4152112cb138c1bae58a5e718f15cb46980c7b84583efa15b
#   Stored in directory: /root/.cache/pip/wheels/05/5f/ca/7c4367734892581bb5ff896f15027a932c551080b2abd3e00d
# Successfully built meta python-levenshtein
# Installing collected packages: click, sniffio, munch, cligj, click-plugins, snuggs, shapely, pyproj, h11, fiona, asgiref, anyio, affine, xyzservices, uvicorn, thefuzz, starlette, rasterio, python-levenshtein, Pillow, meta, geopandas, sodapy, greppo, cinemagoer
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Attempting uninstall: shapely
#     Found existing installation: Shapely 1.8.2
#     Uninstalling Shapely-1.8.2:
#       Successfully uninstalled Shapely-1.8.2
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.0.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Pillow-8.4.0 affine-2.3.1 anyio-3.6.1 asgiref-3.5.2 cinemagoer-2022.2.11 click-8.0.3 click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.21 geopandas-0.10.2 greppo-0.0.25 h11-0.13.0 meta-1.0.2 munch-2.5.0 pyproj-3.2.1 python-levenshtein-0.12.2 rasterio-1.2.10 shapely-1.7.1 sniffio-1.2.0 snuggs-1.4.7 sodapy-2.1.1 starlette-0.16.0 thefuzz-0.19.0 uvicorn-0.15.0 xyzservices-2022.4.0

# %% [markdown]
# # Import Data

# %% [markdown]
# ### Create connection to SF main database
# We use sodapy to access the API

# %%
#used to use sodapy to access the SODA API
sf_database_api = 'data.sfgov.org'
client = Socrata(sf_database_api, None) #use without token
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %% [markdown]
# ### Import database of all street addresses in San francisco
# Available at: https://data.sfgov.org/Geographic-Locations-and-Boundaries/Addresses-Enterprise-Addressing-System/3mea-di5p

# %%
#if you're paging, make sure you provide an $order clause or at a minimum $order=:id.
#That will guarantee that the order of your results will be stable as you page through the dataset. 
sf_address_API_key = "3mea-di5p"

all_address_size = client.get(sf_address_API_key, select = 'COUNT(*)') #return the count of all rows in the dataset, which = dataset size 
all_address_size= int(all_address_size[0]['COUNT'])
limit_size = 5000
street_stride = np.arange(0, all_address_size, limit_size) #this will be used to page through the SF address database with a given pagination chunk

all_address_metadata = client.get_metadata(sf_address_API_key)
all_sf_address_cols = [x['name'] for x in all_address_metadata['columns']]

print(' Total Number of recorded street addresses in SF: ', all_address_size)
# Out:
#  Total Number of recorded street addresses in SF:  223182

# %%
df_all_sf_address_list = list()
for stride_num, stride_start in enumerate(street_stride):

    sf_address_all_request = client.get(sf_address_API_key, limit = limit_size, offset = stride_start, order = 'Address') #without specifying, this will only return 1000 results, need to augment explicitly 
    df_all_sf_address_list.append(pd.DataFrame(sf_address_all_request).drop(['supervisor', 'supname'], axis = 1))

# %%
df_all_sf_address = pd.concat(df_all_sf_address_list).reset_index() #concat list of DFs 
assert df_all_sf_address.address.count() == all_address_size, f"concat DF size equal to count of all database records expected, got: {df_all_sf_address.address.count()}"

# %%
print('Number of addresses listed in this table is ', df_all_sf_address.address.count())
df_all_sf_address.loc[:, 'street_name']  = df_all_sf_address.loc[:, 'street_name'].str.lower()
df_all_sf_address.loc[:, 'address']  = df_all_sf_address.loc[:, 'address'].str.lower()
df_all_sf_address.loc[:, 'street_type']  = df_all_sf_address.loc[:, 'street_type'].str.lower()
df_all_sf_address.head(3).append(df_all_sf_address.tail(3))
# Out:
# Number of addresses listed in this table is  223182
#         index eas_baseid            address address_number   street_name  \
# 0           0     383793     0 alemany blvd              0       alemany
# 1           1     310771        0 balboa st              0        balboa
# 2           2     454709  0 bayview park rd              0  bayview park
# 223179   3179     342858     9 woodland ave              9      woodland
# 223180   3180     379766        9 wright st              9        wright
# 223181   3181     371898         9 young ct              9         young
#
#        street_type zip_code       cnn      longitude     latitude  \
# 0             blvd    94110   2156000  -122.41038038  37.73526758
# 1               st    94121   2672000  -122.48717207   37.7756991
# 2               rd    94124   2836000  -122.39510433  37.71751859
# 223179         ave    94117  13710000  -122.45367508  37.76395976
# 223180          st    94110  13736000  -122.40550365  37.74721756
# 223181          ct    94124  13786000  -122.38616702  37.73646718
#
#                                                     point  \
# 0       {'type': 'Point', 'coordinates': [-122.4103803...
# 1       {'type': 'Point', 'coordinates': [-122.4871720...
# 2       {'type': 'Point', 'coordinates': [-122.3951043...
# 223179  {'type': 'Point', 'coordinates': [-122.4536750...
# 223180  {'type': 'Point', 'coordinates': [-122.4055036...
# 223181  {'type': 'Point', 'coordinates': [-122.3861670...
#
#                           supdist supdistpad numbertext              nhood  \
# 0       SUPERVISORIAL DISTRICT 10         10        TEN            Portola
# 1        SUPERVISORIAL DISTRICT 2         02        TWO   Golden Gate Park
# 2        SUPERVISORIAL DISTRICT 9         09       NINE  Visitacion Valley
# 223179   SUPERVISORIAL DISTRICT 5         05       FIVE       Inner Sunset
# 223180  SUPERVISORIAL DISTRICT 10         10        TEN     Bernal Heights
# 223181  SUPERVISORIAL DISTRICT 10         10        TEN    Treasure Island
#
#        address_number_suffix
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 223179                   NaN
# 223180                   NaN
# 223181                   NaN

# %%
df_all_sf_address['street_name'].loc[df_all_sf_address['street_name'].isin(['the embarcadero'])] = 'embarcadero'

# %% [markdown]
# #### Import movie location data
#
# This project will use data provided by Data SF, specifically a database of Film Locations in San francisco starting from 1924, provided by the San Francisco Film Commission.
#
# For more information see:https://data.sfgov.org/Culture-and-Recreation/Film-Locations-in-San-Francisco/yitu-d5am

# %%
#https://dev.socrata.com/foundry/data.sfgov.org/yitu-d5am for more information on querying
#Dataset Identifier: yitu-d5am

# %%
movie_location_results = client.get("yitu-d5am", limit=5000)

# %%
df_movie_location = pd.DataFrame(movie_location_results)
df_movie_location.head(3).append(df_movie_location.tail(3))
# Out:
#                      title release_year  \
# 0                      180         2011
# 1                      180         2011
# 2                      180         2011
# 1973       Women is Losers         2020
# 1974  Yours, Mine and Ours         1968
# 1975                Zodiac         2007
#
#                                    locations         production_company  \
# 0          Epic Roasthouse (399 Embarcadero)                SPI Cinemas
# 1      Mason & California Streets (Nob Hill)                SPI Cinemas
# 2                        Justin Herman Plaza                SPI Cinemas
# 1973                             Balmy Alley  Look at the Moon Pictures
# 1974                                     NaN         Desilu Productions
# 1975  SF Chronicle Building (901 Mission St)         Paramount Pictures
#
#                 director                                            writer  \
# 0               Jayendra  Umarji Anuradha, Jayendra, Aarthi Sriram, & Suba
# 1               Jayendra  Umarji Anuradha, Jayendra, Aarthi Sriram, & Suba
# 2               Jayendra  Umarji Anuradha, Jayendra, Aarthi Sriram, & Suba
# 1973  Lissette Feliciano                                Lissette Feliciano
# 1974  Melville Shavelson                                  Bob Carroll, Jr.
# 1975       David Fincher                                  James Vanderbilt
#
#               actor_1       actor_2      actor_3         distributor fun_facts
# 0            Siddarth  Nithya Menon  Priya Anand                 NaN       NaN
# 1            Siddarth  Nithya Menon  Priya Anand                 NaN       NaN
# 2            Siddarth  Nithya Menon  Priya Anand                 NaN       NaN
# 1973     Lorenza Izzo      Simu Liu    Liza Weil                 NaN       NaN
# 1974     Lucille Ball   Henry Fonda  Van Johnson      United Artists       NaN
# 1975  Jake Gyllenhaal  Mark Ruffalo          NaN  Paramount Pictures       NaN

# %%
# TODO: word cloud by location?
key_IDs = ['title', 'release_year', 'locations'] #list of important fields i want to use
df_movie_basic_info = df_movie_location.loc[:,key_IDs]
df_movie_basic_info.loc[:, 'locations'] = df_movie_basic_info.loc[:, 'locations'].str.lower()
df_movie_basic_info.head(3)
# Out:
#   title release_year                              locations
# 0   180         2011      epic roasthouse (399 embarcadero)
# 1   180         2011  mason & california streets (nob hill)
# 2   180         2011                    justin herman plaza

# %% [markdown]
# For future reference, I take any NaN (not a number) values in the dataframe and rename them to the string "Empty", for future reference.

# %%
#need to clean NAN in this list, rename every NaN as empty as flag to skip
df_movie_basic_info[df_movie_basic_info.isnull()] = 'Empty'
df_movie_basic_info
# Out:
#                      title release_year  \
# 0                      180         2011
# 1                      180         2011
# 2                      180         2011
# 3                      180         2011
# 4                      180         2011
# ...                    ...          ...
# 1971       Women is Losers         2020
# 1972       Women is Losers         2020
# 1973       Women is Losers         2020
# 1974  Yours, Mine and Ours         1968
# 1975                Zodiac         2007
#
#                                    locations
# 0          epic roasthouse (399 embarcadero)
# 1      mason & california streets (nob hill)
# 2                        justin herman plaza
# 3                    200 block market street
# 4                                  city hall
# ...                                      ...
# 1971                          3202 folsom st
# 1972                           110 pierce st
# 1973                             balmy alley
# 1974                                   Empty
# 1975  sf chronicle building (901 mission st)
#
# [1976 rows x 3 columns]

# %% [markdown]
# ### Import real landmark list and addresses from wikipedia
#
# Some of the places listed in the 'locations' tab are landmarks, not street addresses (eg. City Hall). Therefore, I scrape a wikipedia list of landmarks in SF to hopefully transform landmark-only locations into street addresses.

# %%
# use requests library to pull from wikipedia
sf_landmarks_wiki_url = 'https://en.wikipedia.org/wiki/List_of_San_Francisco_Designated_Landmarks'
wiki_response = requests.get(sf_landmarks_wiki_url)
print(wiki_response)
# Out:
# <Response [200]>

# %%
#use beautiful soup to parse html
soup = BeautifulSoup(wiki_response.text, 'html.parser')
table = soup.find('table', {'class': 'wikitable'})

df_table_string = pd.read_html(str(table))
df_landmark_wiki = pd.DataFrame(df_table_string[0])
df_landmark_wiki.drop(['Image'], axis = 1, inplace = True)
df_landmark_wiki.rename(columns = {'Name': 'Landmark Name'}, inplace = True)
#string formatting step
df_landmark_wiki.loc[:, 'Landmark Name'] =df_landmark_wiki.loc[:, 'Landmark Name'].str.lower()
df_landmark_wiki.loc[:, 'Address'] =df_landmark_wiki.loc[:, 'Address'].str.lower()

df_landmark_wiki.head().append(df_landmark_wiki.tail())
# Out:
#        #                                    Landmark Name  \
# 0      1                                  mission dolores
# 1      2                       old saint mary's cathedral
# 2      3                      bank of california building
# 3      4                           saint patrick's church
# 4      5                   saint francis of assisi church
# 277  279                 arthur h. coleman medical center
# 278  280                                new pullman hotel
# 279  281  piledrivers, bridge, and structural ironworkers
# 280  282                                       hotel utah
# 281  283               dunham, carrigan & hayden building
#
#                      Address        Date  \
# 0            320 dolores st.     4/11/68
# 1         660 california st.     4/11/68
# 2         400 california st.      9/3/68
# 3            756 mission st.      9/3/68
# 4            610 vallejo st.      9/3/68
# 277          6301 3rd street  2018-09-03
# 278  228-248 townsend strret  2018-12-02
# 279    281-247 bryant street  2018-12-02
# 280    500-504 fourth street  2018-12-02
# 281            2 henry adams  2019-01-25
#
#                                         Description[a]
# 0    .mw-parser-output .geo-default,.mw-parser-outp...
# 1    37°47′34″N 122°24′21″W﻿ / ﻿37.79265°N 122.40575°W
# 2    37°47′36″N 122°24′06″W﻿ / ﻿37.7932°N 122.4016°...
# 3    37°47′08″N 122°24′13″W﻿ / ﻿37.785588°N 122.403...
# 4      37°47′56″N 122°24′28″W﻿ / ﻿37.7988°N 122.4077°W
# 277                                               [27]
# 278                                               [28]
# 279                                               [29]
# 280                                               [30]
# 281                                               [31]

# %% [markdown]
# #### Import table of all business names in san francisco

# %% [markdown]
# https://data.sfgov.org/Economy-and-Community/Registered-Business-Locations-San-Francisco/g8m3-pdis

# %%
sf_business_API_key = "g8m3-pdis"

all_business_size = client.get(sf_business_API_key, select = 'COUNT(*)') #return the count of all rows in the dataset, which = dataset size 
all_business_size= int(all_business_size[0]['COUNT'])
limit_size = 5000
street_stride = np.arange(0, all_business_size, limit_size) #this will be used to page through the SF business address database with a given pagination chunk

df_all_sf_business_list = list()
for stride_num, stride_start in enumerate(street_stride):
    df_all_sf_business_stride = client.get(sf_business_API_key, limit = limit_size, offset = stride_start, order = "ttxid") #without specifying, this will only return 1000 results, need to augment explicitly 
    df_all_sf_business_list.append(pd.DataFrame(df_all_sf_business_stride))

# %%
print(all_business_size, len(df_all_sf_business_list), len(df_all_sf_business_list[1]))
df_all_sf_business_list = pd.concat(df_all_sf_business_list).reset_index() #concat list of DFs
# Out:
# 291211 59 5000

# %%
df_all_sf_business_list.head(2)
# Out:
#    index           ttxid certificate_number    ownership_name  \
# 0      0  0000024-02-999            0000024  Eastman Kodak Co
# 1      1  0000028-02-001            0000028   Ferrando Louise
#
#            dba_name full_business_address           city state business_zip  \
# 0  Eastman Kodak Co          343 State St      Rochester    NY        14650
# 1  3101 Laguna Apts        3101 Laguna St  San Francisco    CA   94123-3572
#
#             dba_start_date  ... transient_occupancy_tax  \
# 0  2003-01-01T00:00:00.000  ...                   False
# 1  1993-09-30T00:00:00.000  ...                   False
#
#                                             location  \
# 0  {'type': 'Point', 'coordinates': [-77.61969, 4...
# 1  {'type': 'Point', 'coordinates': [-122.430984,...
#
#                                       uniqueid supervisor_district  \
# 0  0000024-02-999-0000024-3100-3399-01-01-2003                 NaN
# 1  0000028-02-001-0000028-5300-5399-09-30-1993                   2
#
#   neighborhoods_analysis_boundaries location_end_date dba_end_date  lic  \
# 0                               NaN               NaN          NaN  NaN
# 1                            Marina               NaN          NaN  NaN
#
#    lic_code_description business_corridor
# 0                   NaN               NaN
# 1                   NaN               NaN
#
# [2 rows x 28 columns]

# %% [markdown]
# # Parsing locations into addresses
#
# Some of the movie filming locations aren't clear addresses, they'll require some cleaning. I intend to use fuzzy address matching to align the records

# %%
all_unique_locations = list(df_movie_basic_info.loc[:, 'locations'].unique())
print('There are ' + str(len(all_unique_locations)) + ' unique locations listed in this dataframe. A sample of 10 values:')
pprint(all_unique_locations[0:10])
# Out:
# There are 1538 unique locations listed in this dataframe. A sample of 10 values:
# ['epic roasthouse (399 embarcadero)',
#  'mason & california streets (nob hill)',
#  'justin herman plaza',
#  '200 block market street',
#  'city hall',
#  'polk & larkin streets',
#  'randall museum',
#  '555 market st.',
#  'Empty',
#  'the walden house, buena vista park']

# %%
# collect all unique street names
all_unique_street_names = df_all_sf_address['street_name'].unique()  #for some reason this is NOT picking up the embarcadero 
print(f"Per OpenSF's database, there are {all_unique_street_names.shape[0]} unique street names in San Francisco.")
print(' 10 sample street names are: ', all_unique_street_names[0:10])
# Out:
# Per OpenSF's database, there are 1949 unique street names in San Francisco.
#  10 sample street names are:  ['alemany' 'balboa' 'bayview park' 'berry' 'burke' 'donahue' 'earl'
#  'edgehill' 'fitzgerald' 'gibson']

# %%
unique_street_names_in_movie_location = dict()
to_unique_street_match = list()

for i, movie_location in tqdm.tqdm(enumerate(all_unique_locations)):
    matches =[street_name.lower() for street_name in all_unique_street_names if street_name.lower() in movie_location.lower()]
    unique_street_names_in_movie_location[movie_location] = matches

key_indexes = list(unique_street_names_in_movie_location)[3]

print('sample matching street name is', unique_street_names_in_movie_location[key_indexes])
# Out:
# 1538it [00:00, 2184.37it/s]
# sample matching street name is ['market', 'mark']

# %%
# create boolean for rows of ALL SF STREETS that on the unique street name that is a substring of the movie location

df_relevant_sf_address = dict() #create dict where KEY = movie location, VALUE = a DF containing all street addresses on Street of interest (SOI)

for i, movie_location in tqdm.tqdm(enumerate(unique_street_names_in_movie_location)):
    df_relevant_sf_address[movie_location] = [] #in case you had to skip 
    
    if unique_street_names_in_movie_location[movie_location] == []:
        continue

    street_is_substring_bool =  df_all_sf_address.loc[:, 'street_name'].isin(unique_street_names_in_movie_location[movie_location]) #this is list of rows that are in 
    df_relevant_sf_address[movie_location] =df_all_sf_address.loc[street_is_substring_bool, :]
# Out:
# 1538it [00:12, 122.14it/s]

# %%
movie_original_location_dict = dict()
#iterate through ALL movie locations 
unique_street_names_in_movie_location
for iter_num,iter_location in tqdm.tqdm(enumerate(df_movie_basic_info.loc[:,'locations'])):
    movie_original_location_dict[iter_location] = 'Empty'

    if np.logical_or(iter_location == 'Empty', type(df_relevant_sf_address[iter_location]) is list): #it will be a list if no matches for that street address exist
        continue
    
    list_of_choices = list(df_relevant_sf_address[iter_location].loc[:,'address'].values) #index the dict of Dfs to find the df of RELEVANT addresses, turn that into list of values for comparison

    sample_match_highest = process.extractOne(iter_location, list_of_choices, scorer = fuzz.token_sort_ratio) #can pass scorer for extract One
    movie_original_location_dict[iter_location] = sample_match_highest[0] #create key value pair where key is OLD LOCATION, value is NEW location
# Out:
# 1976it [00:23, 84.20it/s]

# %%
df_movie_location_fuzz_guess = pd.DataFrame(movie_original_location_dict.items(), columns = ['Input Name', 'Best Guess'])
df_movie_location_fuzz_guess
# Out:
#                                   Input Name           Best Guess
# 0          epic roasthouse (399 embarcadero)  399 the embarcadero
# 1      mason & california streets (nob hill)      1 california st
# 2                        justin herman plaza          1 justin dr
# 3                    200 block market street     2200 b market st
# 4                                  city hall                Empty
# ...                                      ...                  ...
# 1533                              26 edna st           26 edna st
# 1534                           119 vernon st        119 vernon st
# 1535                          3202 folsom st       3202 folsom st
# 1536                           110 pierce st        110 pierce st
# 1537  sf chronicle building (901 mission st)    1021 b mission st
#
# [1538 rows x 2 columns]

# %%
df_non_matched_locations = df_movie_location_fuzz_guess.loc[df_movie_location_fuzz_guess["Best Guess"] == "Empty", :]
df_non_matched_locations
# Out:
#                     Input Name Best Guess
# 4                    city hall      Empty
# 8                        Empty      Empty
# 15                  coit tower      Empty
# 16    pier 50- end of the pier      Empty
# 33         palace of fine arts      Empty
# ...                        ...        ...
# 1414                cow palace      Empty
# 1438               piers 30-32      Empty
# 1439                   pier 24      Empty
# 1474            antonio street      Empty
# 1530           f train charter      Empty
#
# [81 rows x 2 columns]

# %% [markdown]
# #### Compare unmatched locations to major landmarks

# %%
#list of choices will be the landmark wiki
df_non_matched_locations_guesses = dict()
#df_landmark_wiki.head()
list_of_choices = list(df_landmark_wiki.loc[:,'Landmark Name'].values) #index the dict of Dfs to find the df of RELEVANT addresses, turn that into list of values for comparison

for iter_num,iter_location in tqdm.tqdm(enumerate(df_non_matched_locations.loc[:,'Input Name'])):
    sample_match_highest = process.extractOne(iter_location, list_of_choices, scorer = fuzz.token_set_ratio) #can pass scorer for extract One
    df_non_matched_locations_guesses[iter_location]= sample_match_highest

df_non_matched_locations_guesses
# Out:
# 81it [00:00, 187.27it/s]
# {'"metzger\'s apt" 151 alice b. toklas pl.': ('alemany emergency hospital and health building',
#   44),
#  '145 9th st': ('i. m. scott school', 38),
#  '145 barlett st.': ('haslett warehouse', 45),
#  '2 rowland': ('koshland house', 52),
#  '253 4th ave.': ('geary theater', 42),
#  '2930 3rd street': ('ghirardelli annex-jackson street', 57),
#  '386 4th ave': ('geary theater', 42),
#  '44 montogomery': ('fairmont hotel', 43),
#  '4704 3rd st': ('saint brigid church', 40),
#  'Empty': ('stanyan house', 33),
#  'administration building (treasure island)': ('kohl building', 76),
#  'alamo square': ('ghirardelli square', 67),
#  'alcatraz island': ('italian american bank', 50),
#  'antonio alley': ('washington square', 53),
#  'antonio street': ('ghirardelli annex-jackson street', 60),
#  'areas around transamerica building': ('transamerica building (old fugazi bank building)',
#   76),
#  'at&t stadium': ("jack's restaurant", 48),
#  'aub zam zam bar': ("sam jordan's bar", 59),
#  'barbary coast': ('burr house', 52),
#  'caffe trieste': ('castro theatre', 52),
#  'chrissy field': ('charles dietle house', 48),
#  'city hall': ('san francisco city hall', 100),
#  'claire lilienthal elementary school': ('haas-lilienthal house', 65),
#  'coit tower': ('lillie hitchcock coit tower', 100),
#  'cow palace': ('palace hotel and garden court room', 75),
#  "doc's clock": ('samuels clock', 62),
#  'ele nino traiing cetner, 2920 3rd street': ('market street railway substation',
#   48),
#  'epic roasthouse': ('fireboat house', 69),
#  'eros': ('roos house', 57),
#  'f train': ('trinity church', 48),
#  'f train charter': ('chambers mansion', 58),
#  'ferry building': ('ferry building', 100),
#  "gabbiano's restaurant (ferry building)": ('ferry building', 100),
#  'hall of justice': ('schubert hall', 57),
#  'hamburger haven': ('chambers mansion', 58),
#  'kezar pavillion': ('new era hall', 52),
#  "mcdonald's restaurant (701 3rd street, soma)": ("jack's restaurant", 83),
#  'moscone convention center': ('atherton house', 51),
#  'motel capri': ('cadillac hotel', 64),
#  'mr. s leather': ('atherton house', 54),
#  "orphan andy's": ("sam jordan's bar", 55),
#  'palace of fine arts': ('palace of fine arts', 100),
#  'pier 1': ('hibernia bank', 42),
#  'pier 14': ('hibernia bank', 40),
#  'pier 24': ('hibernia bank', 40),
#  'pier 27': ('hibernia bank', 40),
#  'pier 39': ('hibernia bank', 40),
#  'pier 41': ('hibernia bank', 40),
#  'pier 43': ('hibernia bank', 40),
#  'pier 43 1/2': ('engine co. no. 8, truck co. no. 4', 36),
#  'pier 45': ('hibernia bank', 40),
#  'pier 45 - musee mechanique': ('richard e. queen house', 49),
#  'pier 5': ('hibernia bank', 42),
#  'pier 50': ('hibernia bank', 40),
#  'pier 50- end of the pier': ('house of the flag', 52),
#  'pier 7': ('hibernia bank', 42),
#  'pier 96': ('hibernia bank', 40),
#  'piers 30-32': ('engine co. no. 37, truck co. no. 9', 35),
#  'players arcade at pier 39': ('cable car barn and power house', 51),
#  'punjab': ('bourn mansion', 32),
#  'raw hide ii (280 seventh street)': ('ghirardelli annex-jackson street', 55),
#  'real guitars': ('leale house', 52),
#  "s.s. jeremiah o'brien": ('oriental warehouse', 56),
#  'sf war memorial opera house': ('burr house', 67),
#  'st regis hotel, 125 3rd street': ('hotel utah', 67),
#  "starbucks at 333 o'farrell st.": ('fire department old station no. 2', 46),
#  'sutro baths': ("james lick baths/people's laundry building", 62),
#  'tenderloin neighborhood': ('potrero hill neighborhood house', 69),
#  'terry a. francois blvd.': ('yeon building (san francisco)', 54),
#  'the barbary coast': ('the jackson brewery complex', 59),
#  'the end up, 401 6th streeet': ('bush street temple (soto mission)', 49),
#  'the ferry building': ('ferry building', 100),
#  'the ramp restaurant': ("jack's restaurant", 74),
#  'the stud': ('house of the flag', 55),
#  'the stud, 399 9th street': ('filbert street cottages (bush cottages and the school of basic design and color)',
#   61),
#  'tonga room': ('palace hotel and garden court room', 57),
#  'tonic': ('tobin house', 38),
#  'treasure island': ('ghirardelli square', 48),
#  'w hotel, trace bar - 181 3rd st.': ('hotel utah', 67),
#  "willy's barber shop": ("archbishop's mansion", 56),
#  'wine impression': ('new mission theater', 53)}

# %% [markdown]
# because a lot of these guesses have a low similarity ratio (close to 50%), we threshold the ones below 90%

# %%
#threshold highest matching tokens to extrapolate, cuting 
for key_val in list(df_non_matched_locations_guesses.keys()):
    if int(df_non_matched_locations_guesses[key_val][1]) < 90: #if exceeds threshold 
        df_non_matched_locations_guesses.pop(key_val, None) #delete entry
    else:
        df_non_matched_locations_guesses[key_val] = df_non_matched_locations_guesses[key_val][0]

# %%
df_landmark_location_guess = pd.DataFrame(data = df_non_matched_locations_guesses.items(), columns = ['Input Name', 'Landmark Match'])
df_landmark_location_guess
# Out:
#                                Input Name               Landmark Match
# 0                               city hall      san francisco city hall
# 1                              coit tower  lillie hitchcock coit tower
# 2                     palace of fine arts          palace of fine arts
# 3                          ferry building               ferry building
# 4  gabbiano's restaurant (ferry building)               ferry building
# 5                      the ferry building               ferry building

# %%
for index, key in enumerate(df_non_matched_locations_guesses):
    print(index, key)
    df_non_matched_locations.loc[df_non_matched_locations['Input Name'] == key, 'Best Guess'] = df_non_matched_locations_guesses[key]
# Out:
# 0 city hall
# 1 coit tower
# 2 palace of fine arts
# 3 ferry building
# 4 gabbiano's restaurant (ferry building)
# 5 the ferry building

# %%
num_non_matched_locations = df_non_matched_locations.shape[0]
num_total_locations = len(unique_street_names_in_movie_location)
print( "Proportion of unmatched are ", round(num_non_matched_locations/num_total_locations, 2))
# Out:
# Proportion of unmatched are  0.05

# %% [markdown]
# Given a miss rate of about 5%, I'll continue with a preliminary mapping of the data. First though, I need to join the guesses with the original movie data.

# %%
df_movie_location_fuzz_guess.head(1)
# Out:
#                           Input Name           Best Guess
# 0  epic roasthouse (399 embarcadero)  399 the embarcadero

# %%
df_movie_basic_info.head(1)
# Out:
#   title release_year                          locations
# 0   180         2011  epic roasthouse (399 embarcadero)

# %%
df_all_sf_address.head(1)
# Out:
#    index eas_baseid         address address_number street_name street_type  \
# 0      0     383793  0 alemany blvd              0     alemany        blvd
#
#   zip_code      cnn      longitude     latitude  \
# 0    94110  2156000  -122.41038038  37.73526758
#
#                                                point  \
# 0  {'type': 'Point', 'coordinates': [-122.4103803...
#
#                      supdist supdistpad numbertext    nhood  \
# 0  SUPERVISORIAL DISTRICT 10         10        TEN  Portola
#
#   address_number_suffix
# 0                   NaN

# %%
#join fuzzy guesses with the movie info
df_movies_best_guesses = df_movie_basic_info.merge(df_movie_location_fuzz_guess, how = 'left', left_on = 'locations', right_on = 'Input Name')

# %%
#now join movie guesses with address info
df_movies_full_address = df_movies_best_guesses.merge(df_all_sf_address, how = 'left', left_on = 'Best Guess', right_on = 'address')
df_movies_full_address
# Out:
#                      title release_year  \
# 0                      180         2011
# 1                      180         2011
# 2                      180         2011
# 3                      180         2011
# 4                      180         2011
# ...                    ...          ...
# 1972       Women is Losers         2020
# 1973       Women is Losers         2020
# 1974       Women is Losers         2020
# 1975  Yours, Mine and Ours         1968
# 1976                Zodiac         2007
#
#                                    locations  \
# 0          epic roasthouse (399 embarcadero)
# 1      mason & california streets (nob hill)
# 2                        justin herman plaza
# 3                    200 block market street
# 4                                  city hall
# ...                                      ...
# 1972                          3202 folsom st
# 1973                           110 pierce st
# 1974                             balmy alley
# 1975                                   Empty
# 1976  sf chronicle building (901 mission st)
#
#                                   Input Name           Best Guess   index  \
# 0          epic roasthouse (399 embarcadero)  399 the embarcadero  3438.0
# 1      mason & california streets (nob hill)      1 california st  3866.0
# 2                        justin herman plaza          1 justin dr  4045.0
# 3                    200 block market street     2200 b market st   317.0
# 4                                  city hall                Empty     NaN
# ...                                      ...                  ...     ...
# 1972                          3202 folsom st       3202 folsom st  2913.0
# 1973                           110 pierce st        110 pierce st  2487.0
# 1974                             balmy alley           2 balmy st   993.0
# 1975                                   Empty                Empty     NaN
# 1976  sf chronicle building (901 mission st)    1021 b mission st  1873.0
#
#      eas_baseid              address address_number  street_name  ...  \
# 0        488092  399 the embarcadero            399  embarcadero  ...
# 1        280800      1 california st              1   california  ...
# 2        384248          1 justin dr              1       justin  ...
# 3        486211     2200 b market st           2200       market  ...
# 4           NaN                  NaN            NaN          NaN  ...
# ...         ...                  ...            ...          ...  ...
# 1972     484442       3202 folsom st           3202       folsom  ...
# 1973     289762        110 pierce st            110       pierce  ...
# 1974     275217           2 balmy st              2        balmy  ...
# 1975        NaN                  NaN            NaN          NaN  ...
# 1976     490884    1021 b mission st           1021      mission  ...
#
#      zip_code       cnn      longitude     latitude  \
# 0       94105  12550202  -122.38903515  37.79046991
# 1       94111   3524000  -122.39704304  37.79321375
# 2       94112   7718000  -122.42356684  37.73469234
# 3       94114   8766201  -122.43135917  37.76584073
# 4         NaN       NaN            NaN          NaN
# ...       ...       ...            ...          ...
# 1972    94110   5703000  -122.41375188  37.74709098
# 1973    94117  10418000  -122.43330082  37.77105605
# 1974    94110   2699000  -122.41256654  37.75239947
# 1975      NaN       NaN            NaN          NaN
# 1976    94103   9100000  -122.40891421  37.78033762
#
#                                                   point  \
# 0     {'type': 'Point', 'coordinates': [-122.3890351...
# 1     {'type': 'Point', 'coordinates': [-122.3970430...
# 2     {'type': 'Point', 'coordinates': [-122.4235668...
# 3     {'type': 'Point', 'coordinates': [-122.4313591...
# 4                                                   NaN
# ...                                                 ...
# 1972  {'type': 'Point', 'coordinates': [-122.4137518...
# 1973  {'type': 'Point', 'coordinates': [-122.4333008...
# 1974  {'type': 'Point', 'coordinates': [-122.4125665...
# 1975                                                NaN
# 1976  {'type': 'Point', 'coordinates': [-122.4089142...
#
#                         supdist supdistpad numbertext  \
# 0      SUPERVISORIAL DISTRICT 6         06        SIX
# 1      SUPERVISORIAL DISTRICT 6         06        SIX
# 2      SUPERVISORIAL DISTRICT 8         08      EIGHT
# 3      SUPERVISORIAL DISTRICT 5         05       FIVE
# 4                           NaN        NaN        NaN
# ...                         ...        ...        ...
# 1972   SUPERVISORIAL DISTRICT 8         08      EIGHT
# 1973   SUPERVISORIAL DISTRICT 5         05       FIVE
# 1974  SUPERVISORIAL DISTRICT 10         10        TEN
# 1975                        NaN        NaN        NaN
# 1976   SUPERVISORIAL DISTRICT 3         03      THREE
#
#                                nhood address_number_suffix
# 0     Financial District/South Beach                   NaN
# 1                          Chinatown                   NaN
# 2                      Outer Mission                   NaN
# 3                     Haight Ashbury                     B
# 4                                NaN                   NaN
# ...                              ...                   ...
# 1972                         Mission                   NaN
# 1973                    Hayes Valley                   NaN
# 1974                  Bernal Heights                   NaN
# 1975                             NaN                   NaN
# 1976                 South of Market                     B
#
# [1977 rows x 21 columns]

# %% [markdown]
# # Data Mapping:

# %% [markdown]
# ### Plotly Pass:
# I will use Plotly express,a high level API to access plotly functions

# %%
import plotly.express as px
import folium
from folium.plugins import MarkerCluster
#format for accessing an address lat and lon from the OG address book: df_all_sf_address.loc[1,'point']['coordinates']
df_movies_full_address.head(3)
# Out:
#   title release_year                              locations  \
# 0   180         2011      epic roasthouse (399 embarcadero)
# 1   180         2011  mason & california streets (nob hill)
# 2   180         2011                    justin herman plaza
#
#                               Input Name           Best Guess   index  \
# 0      epic roasthouse (399 embarcadero)  399 the embarcadero  3438.0
# 1  mason & california streets (nob hill)      1 california st  3866.0
# 2                    justin herman plaza          1 justin dr  4045.0
#
#   eas_baseid              address address_number  street_name  ... zip_code  \
# 0     488092  399 the embarcadero            399  embarcadero  ...    94105
# 1     280800      1 california st              1   california  ...    94111
# 2     384248          1 justin dr              1       justin  ...    94112
#
#         cnn      longitude     latitude  \
# 0  12550202  -122.38903515  37.79046991
# 1   3524000  -122.39704304  37.79321375
# 2   7718000  -122.42356684  37.73469234
#
#                                                point  \
# 0  {'type': 'Point', 'coordinates': [-122.3890351...
# 1  {'type': 'Point', 'coordinates': [-122.3970430...
# 2  {'type': 'Point', 'coordinates': [-122.4235668...
#
#                     supdist supdistpad numbertext  \
# 0  SUPERVISORIAL DISTRICT 6         06        SIX
# 1  SUPERVISORIAL DISTRICT 6         06        SIX
# 2  SUPERVISORIAL DISTRICT 8         08      EIGHT
#
#                             nhood address_number_suffix
# 0  Financial District/South Beach                   NaN
# 1                       Chinatown                   NaN
# 2                   Outer Mission                   NaN
#
# [3 rows x 21 columns]

# %%
#import stored API key to access mapbox

from google.colab import drive
drive.mount('/content/drive')

with open('drive/MyDrive/Colab Notebooks/mapbox_token.txt', 'r') as f:
    mapbox_key = f.read().strip()
with open('drive/MyDrive/Colab Notebooks/omdb_api_key.txt', 'r') as omdb:
    omdb_key = omdb.read().strip()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#testing plotting scatterplot
df_movies_full_address.loc[:, ['longitude', 'latitude']] = df_movies_full_address.loc[:, ['longitude', 'latitude']].astype(float)
df_movies_full_address['release_year'] = df_movies_full_address['release_year'].astype(int)
df_movies_full_address['release_decade'] =np.floor(df_movies_full_address['release_year']/10)*10
df_movies_full_address['release_decade'] = df_movies_full_address['release_decade'].astype(int)
df_movies_full_address.head(2)
# Out:
#   title  release_year                              locations  \
# 0   180          2011      epic roasthouse (399 embarcadero)
# 1   180          2011  mason & california streets (nob hill)
#
#                               Input Name           Best Guess   index  \
# 0      epic roasthouse (399 embarcadero)  399 the embarcadero  3438.0
# 1  mason & california streets (nob hill)      1 california st  3866.0
#
#   eas_baseid              address address_number  street_name  ...       cnn  \
# 0     488092  399 the embarcadero            399  embarcadero  ...  12550202
# 1     280800      1 california st              1   california  ...   3524000
#
#     longitude   latitude                                              point  \
# 0 -122.389035  37.790470  {'type': 'Point', 'coordinates': [-122.3890351...
# 1 -122.397043  37.793214  {'type': 'Point', 'coordinates': [-122.3970430...
#
#                     supdist supdistpad numbertext  \
# 0  SUPERVISORIAL DISTRICT 6         06        SIX
# 1  SUPERVISORIAL DISTRICT 6         06        SIX
#
#                             nhood address_number_suffix release_decade
# 0  Financial District/South Beach                   NaN           2010
# 1                       Chinatown                   NaN           2010
#
# [2 rows x 22 columns]

# %%
sorted_year_list = np.sort(df_movies_full_address['release_year'].unique())
sorted_year_list
sorted_decade_list = np.sort(df_movies_full_address['release_decade'].unique())

# %%
#https://plotly.com/python/plotly-express/
#https://medium.com/codex/bring-your-boring-plots-to-life-by-animating-them-acbb8b4b5388
#https://www.visualnoise.io/interactive-maps-with-python-pandas-and-plotly/
#https://plotly.com/python/scattermapbox/

#px.set_mapbox_access_token(mapbox_key)
fig = px.scatter_mapbox(df_movies_full_address, lon = "longitude", lat = "latitude",
                        zoom = 11, hover_name = 'title', hover_data = ['address', 'release_year'],
                        color = "release_decade", color_continuous_scale= 'jet'
                        , height = 600, width= 1000
                        )
fig.update_traces(marker=dict(size=5,  opacity = 0.33))
fig.update_layout(mapbox_style = 'open-street-map')
fig.show()

#animation_frame='release_year', category_orders = {'release_year':sorted_year_list}
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b4468a75-cc18-44c3-999b-a63a66402520" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4468a75-cc18-44c3-999b-a63a66402520")) {                    Plotly.newPlot(                        "b4468a75-cc18-44c3-999b-a63a66402520",                        [{"customdata":[["399 the embarcadero",2011],["1 california st",2011],["1 justin dr",2011],["2200 b market st",2011],[null,2011],["0 larkin st",2011],["2 museum way",2011],["555 market st",2011],[null,2005],["5 buena vista ter",2002],["409 a vallejo st",2002],[null,1982],["1456 a jefferson st",2004],["1 broderick st",2014],["654 crissy field ave",2014],["1541 b powell st",2014],[null,1936],[null,2015],["1 california st",2015],["1 montgomery st",2015],["1 rio ct",2015],["1 rio ct",2015],["2360 a folsom st",1915],["35 golden gate ave",1915],["1 jones st",2012],["849 a leavenworth st",2012],["2421 b larkin st",2012],["2 francisco st",2012],["1 taylor st",2012],["700 e taylor st",2012],["1090 point lobos ave",1938],["2 francisco st",1938],["950 mason st",1938],["143 the embarcadero",2020],[null,2020],["543 connecticut st",2020],["613 a connecticut st",2020],["423 pennsylvania ave",2020],["445 geary st",1950],["55 music concourse dr",2019],["35 golden gate ave",2019],["2154 a market st",2019],["3301 lyon st",2019],["717 grant ave",2019],["3138 b washington st",2019],["1521 b golden gate ave",2019],["51 california ave",2019],["1 haight st",2019],["1 haight st",2019],[null,2019],[null,2019],["1 19th ave",2019],["10 22nd ave",2019],["2 museum way",2019],["60 a fair ave",2019],["226 el camino del mar",2019],["399 san fernando way",2015],["15 romolo st",2015],[null,2015],["1 mclaren ave",2015],[null,2015],["300 francisco st",2015],["33 spruce st",2015],["373 broadway",2015],["2534 mission st",2015],["10 bernal heights blvd",2015],["610 r jackson st",2015],["679 madrid st",2015],["3117 16th st",2015],["582 market st",2015],["375 laguna honda blvd",2015],["3232 jackson st",2015],["1301 a illinois st",2015],["27 a van ness ave",1973],["3355 geary blvd",1973],[null,2004],["0 the embarcadero",1978],["950 mason st",1978],["1076 a francisco st",1978],["490 a broadway",1978],[null,1990],["1122 a elm st",2015],["819 d lombard st",2015],["601 buena vista ave west",2015],["2130 a jones st",2015],["1039 b broadway",2015],["738 a washington st",2015],["2731 b california st",2015],["405 davis ct",2015],["27 a van ness ave",2015],["1039 b broadway",2015],["1238 c broadway",2015],["1 california st",2015],["10 palm ave",2015],["490 geary st",2018],["544 jones st",2018],["201 a missouri st",2018],["1 telegraph hill blvd",2018],["1 ina ct",2018],["1 russian hill pl",2018],["1359 b sacramento st",2018],["849 a leavenworth st",2018],["845 b montgomery st",2018],["2131 b mason st",2018],["2033 b leavenworth st",2018],["671 b green st",2018],["845 a montgomery st",2018],["25 java st",2018],["0 the embarcadero",2018],["836 a north point st",2018],[null,2018],["1 jefferson st",2018],["531 a jackson st",2018],["845 a montgomery st",2018],["965 e hyde st",2018],["26 saint louis aly",2018],["40 leavenworth st",2018],["15 service st",2018],["18 ocean ave",1998],["475 california st",1997],["1100 california st",1997],["0 the embarcadero",1997],["2 francisco st",1997],["1 dolores ter",2018],["738 washington st",2018],["1 waverly pl",2018],["700 grant ave",2018],["0 larkin st",2018],["126 a texas st",2018],["2751 mission st",2018],[null,2018],["3301 lyon st",2018],["1 sutter st",2018],["415 a haight st",2018],["10 bernal heights blvd",2018],["542 a castro st",2018],["2 steiner st",2018],["2 francisco st",2018],["2 plaza st",2018],[null,2018],["1140 a hyde st",1978],[null,1985],["2 francisco st",1985],["325 china basin st",1985],["3 ...

# %% [markdown]
# ### Import IMDB data to better sort datapoints
# Going to be using the cinemagoer package (available at cinemagoer.github.io)

# %%
#IMPORT IMDB datasets from https://cinemagoer.github.io/
movie_db = Cinemagoer()

#create df of movie information
all_movie_titles = df_movies_full_address['title'].unique().astype(list)
movie_years = df_movies_full_address.groupby('title')['release_year'].first().reset_index()

movie_years
# Out:
#                       title  release_year
# 0                       180          2011
# 1    24 Hours on Craigslist          2005
# 2     40 Days and 40 Nights          2002
# 3                  48 Hours          1982
# 4            50 First Dates          2004
# ..                      ...           ...
# 320            Woman on Top          2000
# 321        Woman on the Run          1950
# 322         Women is Losers          2020
# 323    Yours, Mine and Ours          1968
# 324                  Zodiac          2007
#
# [325 rows x 2 columns]

# %%
#use OMDB requests- 1000 requests per day https://www.omdbapi.com/
#OMDB api key is omdb_key

limit_request = 999

omdb_url =  f'http://www.omdbapi.com/?apikey={omdb_key}'
#set current query values and params
query_movie_year = movie_years.loc[111, 'release_year']
query_movie_title =movie_years.loc[111, 'title']
params = {"t": query_movie_title, "y":query_movie_year, "plot": 'full'}
#run current API request 
omdb_movie_search = requests.get(omdb_url, params = params).json()
omdb_movie_search.update({'release_year':query_movie_year, 'searched_title' : query_movie_title}) #add key value pairs that are the search terms used 
omdb_request_list.append(omdb_movie_search)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-f1d15bbb7406> in <module>()
#      12 omdb_movie_search = requests.get(omdb_url, params = params).json()
#      13 omdb_movie_search.update({'release_year':query_movie_year, 'searched_title' : query_movie_title}) #add key value pairs that are the search terms used
# ---> 14 omdb_request_list.append(omdb_movie_search)
#
# NameError: name 'omdb_request_list' is not defined

# %%
#1.5 min for full loop ## FOR loop for OMDB request
omdb_request_list = list()
#use itertuples to iterate over rows of movie_years dataframe
for row in movie_years.itertuples(name = None):
    query_movie_year = row[2]
    query_movie_title =row[1]    
    params = {"t": query_movie_title, "y":query_movie_year, "plot": 'full'}
    #run current API request 
    omdb_movie_search = requests.get(omdb_url, params = params).json()
    omdb_movie_search.update({'release_year':query_movie_year, 'searched_title' : query_movie_title}) #add key value pairs that are the search terms used 
    omdb_request_list.append(omdb_movie_search)

# %%
df_omdb_info = pd.DataFrame(omdb_request_list)
df_omdb_info #some rows are nan

# %%
#download film info database
df_omdb_info.to_csv('drive/MyDrive/dataframe_omdb_info.csv')

# %%
df_omdb_info['Genre'].unique()

# %% [markdown]
# #### MAP: Using open source maps to plot points on the map
# https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6

# %%
##WIP: movie poster GAN
"""
https://www.omdbapi.com/ #has a poster API, 1000 api pull .
https://imdb-api.com/api # 100 api request/day
https://developers.themoviedb.org/3/getting-started/introduction #no rate limit stated 

#IDEA, make a GAN that creates FAKE MOVIE POSTERS FOR A REGION????? #is there enough input data 
https://www.johnkraszewski.com/media-synthesis
https://www.kaggle.com/neha1703/movie-genre-from-its-poster/version/3
https://github.com/benckx/dnn-movie-posters
https://github.com/siddtheshah/poster-gan"""
