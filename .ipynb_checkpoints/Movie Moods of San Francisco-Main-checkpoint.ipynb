# %% [markdown]
# # Can you quantify the culture of a city?
# ## Studying the many moods of San Francisco through movies, using Python, Pandas, and Plotly:
#
#
# *“Cities, like dreams, are made of desires and fears, even if the thread of their discourse is secret, their rules are absurd, their perspectives deceitful, and everything conceals something else.”*
# ― Italo Calvino, Invisible Cities
#
# In this notebook I hope to reveal some of the threads of San Francisco's outline, as used for dramatic effect in films. The city government of San Francisco keeps records, going back nearly to the dawn of film, of all the locations of the city that have been featured on celluloid. The data is messy, so I perform data cleaning and pre-processing before mapping the data and examining its structure.
#
# Can we quantify the "mood" of a neighborhood based on the kinds of movies that have used it for locations? We will find out!
# Special thanks to the city of San Francisco for making these records readily available!

# %%
#import libraries
# %cd "G:\My Drive\Colab Notebooks\Function .py Storage"
# !conda install shapely
# %pip install -r requirements_movie_sf.txt
import sys, os
    
import pandas as pd
import numpy as np
import scipy as sc
import requests
import io
import gzip
import imdb
# !pip install geopandas greppo sodapy bs4 thefuzz[speedup] cinemagoer
from imdb import Cinemagoer

from thefuzz import fuzz, process #https://github.com/seatgeek/thefuzz, updated version of fuzzy wuzzy
from bs4 import BeautifulSoup
from re import search
import geopandas
#import greppo
import sodapy
from sodapy import Socrata

import seaborn as sns
import matplotlib.pyplot as plt
from pprint import pprint

import tqdm
import datetime as dt
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# Collecting shapely@ https://github.com/cgohlke/geospatial-wheels/releases/download/v2025.1.20/shapely-2.0.6-cp312-cp312-win_amd64.whl (from -r requirements_movie_sf.txt (line 33))Note: you may need to restart the kernel to use updated packages.
#
#   Downloading https://github.com/cgohlke/geospatial-wheels/releases/download/v2025.1.20/shapely-2.0.6-cp312-cp312-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ---------------------------------------- 1.5/1.5 MB 37.7 MB/s eta 0:00:00
# Requirement already satisfied: seaborn==0.12.2 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 4)) (0.12.2)
# Requirement already satisfied: scikit-learn==1.5.2 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 5)) (1.5.2)
# Requirement already satisfied: matplotlib==3.7.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 6)) (3.7.0)
# Requirement already satisfied: pandas_flavor in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 7)) (0.6.0)
# Requirement already satisfied: pingouin in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 8)) (0.5.5)
# Requirement already satisfied: numpy<2 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 9)) (1.26.4)
# Requirement already satisfied: xlrd>=2.0.1 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 10)) (2.0.1)
# Requirement already satisfied: datetime in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 11)) (5.5)
# Requirement already satisfied: tqdm in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 12)) (4.67.1)
# Requirement already satisfied: setuptools>=42 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 13)) (75.1.0)
# Requirement already satisfied: dill>=0.3.9 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 14)) (0.3.9)
# Requirement already satisfied: pyarrow in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 15)) (18.1.0)
# Requirement already satisfied: fastparquet in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 16)) (2024.11.0)
# Requirement already satisfied: openpyxl in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 17)) (3.1.5)
# Requirement already satisfied: plotly in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 19)) (5.24.1)
# Requirement already satisfied: folium in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 20)) (0.19.4)
# Requirement already satisfied: streamlit in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 21)) (1.41.1)
# Requirement already satisfied: openai in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 23)) (1.59.8)
# Requirement already satisfied: python-dotenv in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 24)) (1.0.1)
# Requirement already satisfied: geos in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 25)) (0.2.3)
# Requirement already satisfied: geopandas in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 26)) (0.14.4)
# Requirement already satisfied: click==8.0.3 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 28)) (8.0.3)
# Requirement already satisfied: sodapy in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 29)) (2.2.0)
# Requirement already satisfied: bs4 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 30)) (0.0.2)
# Requirement already satisfied: thefuzz in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 31)) (0.22.1)
# Requirement already satisfied: cinemagoer in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from -r requirements_movie_sf.txt (line 32)) (2023.5.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from seaborn==0.12.2->-r requirements_movie_sf.txt (line 4)) (2.2.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from scikit-learn==1.5.2->-r requirements_movie_sf.txt (line 5)) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from scikit-learn==1.5.2->-r requirements_movie_sf.txt (line 5)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from scikit-learn==1.5.2->-r requirements_movie_sf.txt (line 5)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from matplotlib==3.7.0->-r requirements_movie_sf.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from matplotlib==3.7.0->-r requirements_movie_sf.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from matplotlib==3.7.0->-r requirements_movie_sf.txt (line 6)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from matplotlib==3.7.0->-r requirements_movie_sf.txt (line 6)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from matplotlib==3.7.0->-r requirements_movie_sf.txt (line 6)) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from matplotlib==3.7.0->-r requirements_movie_sf.txt (line 6)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from matplotlib==3.7.0->-r requirements_movie_sf.txt (line 6)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from matplotlib==3.7.0->-r requirements_movie_sf.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from click==8.0.3->-r requirements_movie_sf.txt (line 28)) (0.4.6)
# Requirement already satisfied: xarray in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from pandas_flavor->-r requirements_movie_sf.txt (line 7)) (2024.11.0)
# Requirement already satisfied: statsmodels in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from pingouin->-r requirements_movie_sf.txt (line 8)) (0.14.4)
# Requirement already satisfied: tabulate in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from pingouin->-r requirements_movie_sf.txt (line 8)) (0.9.0)
# Requirement already satisfied: zope.interface in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from datetime->-r requirements_movie_sf.txt (line 11)) (7.2)
# Requirement already satisfied: pytz in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from datetime->-r requirements_movie_sf.txt (line 11)) (2024.1)
# Requirement already satisfied: cramjam>=2.3 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from fastparquet->-r requirements_movie_sf.txt (line 16)) (2.9.1)
# Requirement already satisfied: fsspec in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from fastparquet->-r requirements_movie_sf.txt (line 16)) (2024.12.0)
# Requirement already satisfied: et-xmlfile in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from openpyxl->-r requirements_movie_sf.txt (line 17)) (2.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from plotly->-r requirements_movie_sf.txt (line 19)) (9.0.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from folium->-r requirements_movie_sf.txt (line 20)) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from folium->-r requirements_movie_sf.txt (line 20)) (3.1.4)
# Requirement already satisfied: requests in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from folium->-r requirements_movie_sf.txt (line 20)) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from folium->-r requirements_movie_sf.txt (line 20)) (2025.1.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from streamlit->-r requirements_movie_sf.txt (line 21)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from streamlit->-r requirements_movie_sf.txt (line 21)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from streamlit->-r requirements_movie_sf.txt (line 21)) (5.5.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from streamlit->-r requirements_movie_sf.txt (line 21)) (5.29.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from streamlit->-r requirements_movie_sf.txt (line 21)) (13.9.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from streamlit->-r requirements_movie_sf.txt (line 21)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from streamlit->-r requirements_movie_sf.txt (line 21)) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from streamlit->-r requirements_movie_sf.txt (line 21)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from streamlit->-r requirements_movie_sf.txt (line 21)) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from streamlit->-r requirements_movie_sf.txt (line 21)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from streamlit->-r requirements_movie_sf.txt (line 21)) (6.4.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from openai->-r requirements_movie_sf.txt (line 23)) (4.6.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from openai->-r requirements_movie_sf.txt (line 23)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from openai->-r requirements_movie_sf.txt (line 23)) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from openai->-r requirements_movie_sf.txt (line 23)) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from openai->-r requirements_movie_sf.txt (line 23)) (2.10.5)
# Requirement already satisfied: sniffio in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from openai->-r requirements_movie_sf.txt (line 23)) (1.3.0)
# Requirement already satisfied: flask in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from geos->-r requirements_movie_sf.txt (line 25)) (2.2.5)
# Requirement already satisfied: lxml in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from geos->-r requirements_movie_sf.txt (line 25)) (5.3.0)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from geopandas->-r requirements_movie_sf.txt (line 26)) (1.10.1)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from geopandas->-r requirements_movie_sf.txt (line 26)) (3.7.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from bs4->-r requirements_movie_sf.txt (line 30)) (4.12.3)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from thefuzz->-r requirements_movie_sf.txt (line 31)) (3.11.0)
# Requirement already satisfied: SQLAlchemy in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from cinemagoer->-r requirements_movie_sf.txt (line 32)) (2.0.37)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements_movie_sf.txt (line 21)) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements_movie_sf.txt (line 21)) (1.22.0)
# Requirement already satisfied: idna>=2.8 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from anyio<5,>=3.5.0->openai->-r requirements_movie_sf.txt (line 23)) (3.7)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from fiona>=1.8.21->geopandas->-r requirements_movie_sf.txt (line 26)) (24.2.0)
# Requirement already satisfied: certifi in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from fiona>=1.8.21->geopandas->-r requirements_movie_sf.txt (line 26)) (2024.8.30)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from fiona>=1.8.21->geopandas->-r requirements_movie_sf.txt (line 26)) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from fiona>=1.8.21->geopandas->-r requirements_movie_sf.txt (line 26)) (0.7.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements_movie_sf.txt (line 21)) (4.0.12)
# Requirement already satisfied: httpcore==1.* in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from httpx<1,>=0.23.0->openai->-r requirements_movie_sf.txt (line 23)) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements_movie_sf.txt (line 23)) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from jinja2>=2.9->folium->-r requirements_movie_sf.txt (line 20)) (2.1.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from pandas>=0.25->seaborn==0.12.2->-r requirements_movie_sf.txt (line 4)) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirements_movie_sf.txt (line 23)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirements_movie_sf.txt (line 23)) (2.27.2)
# Requirement already satisfied: six>=1.5 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.7.0->-r requirements_movie_sf.txt (line 6)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from requests->folium->-r requirements_movie_sf.txt (line 20)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from requests->folium->-r requirements_movie_sf.txt (line 20)) (2.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from rich<14,>=10.14.0->streamlit->-r requirements_movie_sf.txt (line 21)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from rich<14,>=10.14.0->streamlit->-r requirements_movie_sf.txt (line 21)) (2.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from beautifulsoup4->bs4->-r requirements_movie_sf.txt (line 30)) (2.5)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from flask->geos->-r requirements_movie_sf.txt (line 25)) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from flask->geos->-r requirements_movie_sf.txt (line 25)) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from SQLAlchemy->cinemagoer->-r requirements_movie_sf.txt (line 32)) (3.1.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from statsmodels->pingouin->-r requirements_movie_sf.txt (line 8)) (1.0.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements_movie_sf.txt (line 21)) (5.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements_movie_sf.txt (line 21)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements_movie_sf.txt (line 21)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements_movie_sf.txt (line 21)) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\13car\anaconda3\envs\local_colab\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements_movie_sf.txt (line 21)) (0.1.2)

# %%
print(sys.version)
# Out:
# 3.12.8 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:48:34) [MSC v.1929 64 bit (AMD64)]

# %%
# %whos
# Out:
# Variable        Type        Data/Info
# -------------------------------------
# BeautifulSoup   type        <class 'bs4.BeautifulSoup'>
# Cinemagoer      function    <function IMDb at 0x0000022125F4D120>
# Socrata         type        <class 'sodapy.socrata.Socrata'>
# dt              module      <module 'datetime' from '<...>colab\\Lib\\datetime.py'>
# fuzz            module      <module 'thefuzz.fuzz' fr<...>kages\\thefuzz\\fuzz.py'>
# geopandas       module      <module 'geopandas' from <...>\geopandas\\__init__.py'>
# gzip            module      <module 'gzip' from 'C:\\<...>cal_colab\\Lib\\gzip.py'>
# imdb            module      <module 'imdb' from 'C:\\<...>ages\\imdb\\__init__.py'>
# io              module      <module 'io' from 'C:\\Us<...>local_colab\\Lib\\io.py'>
# np              module      <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# os              module      <module 'os' from 'C:\\Us<...>local_colab\\Lib\\os.py'>
# pd              module      <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt             module      <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# pprint          function    <function pprint at 0x00000221764FA3E0>
# process         module      <module 'thefuzz.process'<...>es\\thefuzz\\process.py'>
# requests        module      <module 'requests' from '<...>\\requests\\__init__.py'>
# sc              module      <module 'scipy' from 'C:\<...>ges\\scipy\\__init__.py'>
# search          function    <function search at 0x0000022174166480>
# sns             module      <module 'seaborn' from 'C<...>s\\seaborn\\__init__.py'>
# sodapy          module      <module 'sodapy' from 'C:<...>es\\sodapy\\__init__.py'>
# sys             module      <module 'sys' (built-in)>
# tqdm            module      <module 'tqdm' from 'C:\\<...>ages\\tqdm\\__init__.py'>
# warnings        module      <module 'warnings' from '<...>colab\\Lib\\warnings.py'>

# %% [markdown]
# # Import Data

# %% [markdown]
# ### Create connection to SF main database
# We use sodapy to access the API

# %%
soda_key = open('sodapy_app_token_v1.txt', 'r').read().strip()

# %%
# Out:
# 'u5bfm8zxAw78quX4cmd7BOIqR'

# %%
#used to use sodapy to access the SODA API
auth = []
sf_database_api = 'data.sfgov.org'
client = Socrata(sf_database_api, soda_key) #use without token

# %% [markdown]
# ### Import database of all street addresses in San francisco
# Available at: https://data.sfgov.org/Geographic-Locations-and-Boundaries/Addresses-Enterprise-Addressing-System/3mea-di5p

# %%
#if you're paging, make sure you provide an $order clause or at a minimum $order=:id.
#That will guarantee that the order of your results will be stable as you page through the dataset. 
sf_address_API_key = "3mea-di5p"

all_address_size = client.get(sf_address_API_key, select = 'COUNT(*)') #return the count of all rows in the dataset, which = dataset size 
all_address_size= int(all_address_size[0]['COUNT'])
limit_size = 5000
street_stride = np.arange(0, all_address_size, limit_size) #this will be used to page through the SF address database with a given pagination chunk

all_address_metadata = client.get_metadata(sf_address_API_key)
all_sf_address_cols = [x['name'] for x in all_address_metadata['columns']]

print(' Total Number of recorded street addresses in SF: ', all_address_size)
# Out:
#  Total Number of recorded street addresses in SF:  223896

# %%
len(street_stride)
# Out:
# 45

# %%
raw_df_file_name = f"Raw SF address df.csv"
load_saved_csv = False
save_imported_csv = not load_saved_csv
print(load_saved_csv, save_imported_csv)
if not load_saved_csv:
    df_all_sf_address_list = list()
    for stride_num, stride_start in enumerate(street_stride):
        print(f"Running stride {stride_num} of {len(street_stride)}")
        sf_address_all_request = client.get(sf_address_API_key, limit = limit_size, offset = stride_start, order = 'Address') #without specifying, this will only return 1000 results, need to augment explicitly 
        df_all_sf_address_list.append(pd.DataFrame(sf_address_all_request).drop(['supervisor', 'supname'], axis = 1))
    df_all_sf_address = pd.concat(df_all_sf_address_list).reset_index() #concat list of DFs 
    assert df_all_sf_address.address.count() == all_address_size, f"concat DF size equal to count of all database records expected, got: {df_all_sf_address.address.count()}"
    #end loop over strides
    print('Number of addresses listed in this table is ', df_all_sf_address.address.count())
    df_all_sf_address.loc[:, 'street_name']  = df_all_sf_address.loc[:, 'street_name'].str.lower()
    df_all_sf_address.loc[:, 'address']  = df_all_sf_address.loc[:, 'address'].str.lower()
    df_all_sf_address.loc[:, 'street_type']  = df_all_sf_address.loc[:, 'street_type'].str.lower()
    df_all_sf_address.head(3)
    df_all_sf_address['street_name'].loc[df_all_sf_address['street_name'].isin(['the embarcadero'])] = 'embarcadero'
else: #else import csv 
    df_all_sf_address= pd.read_csv(raw_df_file_name)

if save_imported_csv:
    df_all_sf_address.to_csv(raw_df_file_name)
# Out:
# False True
# Running stride 0 of 45
# Running stride 1 of 45
# Running stride 2 of 45
# Running stride 3 of 45
# Running stride 4 of 45
# Running stride 5 of 45
# Running stride 6 of 45
# Running stride 7 of 45
# Running stride 8 of 45
# Running stride 9 of 45
# Running stride 10 of 45
# Running stride 11 of 45
# Running stride 12 of 45
# Running stride 13 of 45
# Running stride 14 of 45
# Running stride 15 of 45
# Running stride 16 of 45
# Running stride 17 of 45
# Running stride 18 of 45
# Running stride 19 of 45
# Running stride 20 of 45
# Running stride 21 of 45
# Running stride 22 of 45
# Running stride 23 of 45
# Running stride 24 of 45
# Running stride 25 of 45
# Running stride 26 of 45
# Running stride 27 of 45
# Running stride 28 of 45
# Running stride 29 of 45
# Running stride 30 of 45
# Running stride 31 of 45
# Running stride 32 of 45
# Running stride 33 of 45
# Running stride 34 of 45
# Running stride 35 of 45
# Running stride 36 of 45
# Running stride 37 of 45
# Running stride 38 of 45
# Running stride 39 of 45
# Running stride 40 of 45
# Running stride 41 of 45
# Running stride 42 of 45
# Running stride 43 of 45
# Running stride 44 of 45
# Number of addresses listed in this table is  223896

# %% [markdown]
# #### Import movie location data
#
# This project will use data provided by Data SF, specifically a database of Film Locations in San francisco starting from 1924, provided by the San Francisco Film Commission.
#
# For more information see:https://data.sfgov.org/Culture-and-Recreation/Film-Locations-in-San-Francisco/yitu-d5am

# %%
#https://dev.socrata.com/foundry/data.sfgov.org/yitu-d5am for more information on querying
#Dataset Identifier: yitu-d5am

# %%
movie_location_results = client.get("yitu-d5am", limit=5000)

# %%
df_movie_location = pd.DataFrame(movie_location_results)
df_movie_location.head(3)
# Out:
#                 title release_year                         locations  \
# 0  Always Be My Maybe         2019                     717 Grant Ave
# 1                DEVS         2020  Filbert btwn Powell and Stockton
# 2      Faces of Death         1978                               NaN
#
#       production_company         distributor          director  \
# 0  Isla Productions, LLC             Netflix   Nahnatchka Khan
# 1      Minim Productions          FX Network      Alex Garland
# 2      F.O.D Productions  Aquarius Releasing  Conan Le Cilaire
#
#                                     writer        actor_1        actor_2  \
# 0  Michael Golamco, Randall Park, Ali Wong       Ali Wong   Randall Park
# 1                             Alex Garland  Sonoya Mizuno  Nick Offerman
# 2                               Alan Black   Michael Carr            NaN
#
#         actor_3  ...     longitude    latitude analysis_neighborhood  \
# 0  Keanu Reeves  ...  -122.4063975  37.7936544             Chinatown
# 1        Jin Ha  ...  -122.4111093   37.801299           North Beach
# 2           NaN  ...           NaN         NaN                   NaN
#
#   supervisor_district               data_as_of           data_loaded_at  \
# 0                   3  2024-12-06T12:17:47.000  2024-12-18T14:30:38.000
# 1                   3  2024-12-06T12:17:47.000  2024-12-18T14:30:38.000
# 2                 NaN  2024-12-06T12:17:47.000  2024-12-18T14:30:38.000
#
#   :@computed_region_6qbp_sg9q :@computed_region_ajp5_b2md  \
# 0                         104                           6
# 1                         106                          23
# 2                         NaN                         NaN
#
#   :@computed_region_26cr_cadq fun_facts
# 0                           3       NaN
# 1                           3       NaN
# 2                         NaN       NaN
#
# [3 rows x 21 columns]

# %%
# TODO: word cloud by location?
key_IDs = ['title', 'release_year', 'locations'] #list of important fields i want to use
df_movie_basic_info = df_movie_location.loc[:,key_IDs]
df_movie_basic_info.loc[:, 'locations'] = df_movie_basic_info.loc[:, 'locations'].str.lower()
df_movie_basic_info.head(3)
# Out:
#                 title release_year                         locations
# 0  Always Be My Maybe         2019                     717 grant ave
# 1                DEVS         2020  filbert btwn powell and stockton
# 2      Faces of Death         1978                               NaN

# %% [markdown]
# For future reference, I take any NaN (not a number) values in the dataframe and rename them to the string "Empty", for future reference.

# %%
#need to clean NAN in this list, rename every NaN as empty as flag to skip
df_movie_basic_info[df_movie_basic_info.isnull()] = 'Empty'
df_movie_basic_info
# Out:
#                          title release_year  \
# 0           Always Be My Maybe         2019
# 1                         DEVS         2020
# 2               Faces of Death         1978
# 3               Romeo Must Die         2000
# 4                  San Andreas         2015
# ...                        ...          ...
# 2079           Women is Losers         2020
# 2080                  Godzilla         2014
# 2081                Cardinal X         2015
# 2082  The Matrix Resurrections         2021
# 2083    24 Hours on Craigslist         2005
#
#                                    locations
# 0                              717 grant ave
# 1           filbert btwn powell and stockton
# 2                                      Empty
# 3                         embarcadero street
# 4                                 fort baker
# ...                                      ...
# 2079                          2712 bryant st
# 2080                                  pier 1
# 2081                       100 alemany blvd.
# 2082  montgomery between washington and bush
# 2083                                   Empty
#
# [2084 rows x 3 columns]

# %% [markdown]
# ### Import real landmark list and addresses from wikipedia
#
# Some of the places listed in the 'locations' tab are landmarks, not street addresses (eg. City Hall). Therefore, I scrape a wikipedia list of landmarks in SF to hopefully transform landmark-only locations into street addresses.

# %%
# use requests library to pull from wikipedia- https://medium.com/analytics-vidhya/web-scraping-wiki-tables-using-beautifulsoup-and-python-6b9ea26d8722
sf_landmarks_wiki_url = 'https://en.wikipedia.org/wiki/List_of_San_Francisco_Designated_Landmarks'
wiki_response = requests.get(sf_landmarks_wiki_url)
print(wiki_response)
# Out:
# <Response [200]>

# %%
#use beautiful soup to parse html
soup = BeautifulSoup(wiki_response.text, 'html.parser')
table_string = 'wikitable sortable jquery-tablesorter' #found using inspect element
table = soup.find('table', {'class':  'wikitable sortable'}) #this is the only string that works

# %%
df_table_string = pd.read_html(str(table))
df_landmark_wiki = pd.DataFrame(df_table_string[0])
df_landmark_wiki
# Out:
#        #                                      Name  Image  \
# 0      1                           Mission Dolores    NaN
# 1      2                Old Saint Mary's Cathedral    NaN
# 2      3               Bank of California Building    NaN
# 3      4                    Saint Patrick's Church    NaN
# 4      5            Saint Francis of Assisi Church    NaN
# ..   ...                                       ...    ...
# 304  307      Site of the Compton’s Cafeteria Riot    NaN
# 305  308             St. James Presbyterian Church    NaN
# 306  309  Church for the Fellowship of All Peoples    NaN
# 307  310                   Parkside Branch Library    NaN
# 308  311                       Colombo Market Arch    NaN
#
#                                                Address    Date designated  \
# 0                                   320 Dolores Street     April 11, 1968
# 1                                660 California Street     April 11, 1968
# 2                                400 California Street  September 3, 1968
# 3                                   756 Mission Street  September 3, 1968
# 4                                   610 Vallejo Street  September 3, 1968
# ..                                                 ...                ...
# 304  Turk and Taylor Streets intersection, with por...  November 29, 2022
# 305                                  240 Leland Avenue  December 13, 2022
# 306                                 2041 Larkin Street      June 27, 2023
# 307                                1200 Taraval Street      July 25, 2023
# 308                                   600 Front Street    October 3, 2023
#
#                                            Description   Type
# 0    37°45′51″N 122°25′36″W﻿ / ﻿37.7642°N 122.4266°...   NRHP
# 1    37°47′34″N 122°24′21″W﻿ / ﻿37.79265°N 122.40575°W  CHISL
# 2    37°47′36″N 122°24′06″W﻿ / ﻿37.7932°N 122.4016°...   SFDL
# 3    37°47′08″N 122°24′13″W﻿ / ﻿37.785588°N 122.403...   SFDL
# 4      37°47′56″N 122°24′28″W﻿ / ﻿37.7988°N 122.4077°W   SFDL
# ..                                                 ...    ...
# 304                                                NaN   SFDL
# 305                                                NaN   SFDL
# 306                                                NaN   SFDL
# 307                                                NaN   SFDL
# 308                    within Sydney Walton Square[27]   SFDL
#
# [309 rows x 7 columns]

# %%
df_landmark_wiki.drop(['Image', 'Date designated'], axis = 1, inplace = True)
df_landmark_wiki.rename(columns = {'Name': 'Landmark Name'}, inplace = True)
#string formatting step
df_landmark_wiki.loc[:, 'Landmark Name'] =df_landmark_wiki.loc[:, 'Landmark Name'].str.lower()
df_landmark_wiki.loc[:, 'Address'] =df_landmark_wiki.loc[:, 'Address'].str.lower()

df_landmark_wiki.head()
# Out:
#    #                   Landmark Name                Address  \
# 0  1                 mission dolores     320 dolores street
# 1  2      old saint mary's cathedral  660 california street
# 2  3     bank of california building  400 california street
# 3  4          saint patrick's church     756 mission street
# 4  5  saint francis of assisi church     610 vallejo street
#
#                                          Description   Type
# 0  37°45′51″N 122°25′36″W﻿ / ﻿37.7642°N 122.4266°...   NRHP
# 1  37°47′34″N 122°24′21″W﻿ / ﻿37.79265°N 122.40575°W  CHISL
# 2  37°47′36″N 122°24′06″W﻿ / ﻿37.7932°N 122.4016°...   SFDL
# 3  37°47′08″N 122°24′13″W﻿ / ﻿37.785588°N 122.403...   SFDL
# 4    37°47′56″N 122°24′28″W﻿ / ﻿37.7988°N 122.4077°W   SFDL

# %% [markdown]
# #### Import table of all business names in san francisco

# %% [markdown]
# https://data.sfgov.org/Economy-and-Community/Registered-Business-Locations-San-Francisco/g8m3-pdis

# %%
sf_business_API_key = "g8m3-pdis"

all_business_size = client.get(sf_business_API_key, select = 'COUNT(*)') #return the count of all rows in the dataset, which = dataset size 
all_business_size= int(all_business_size[0]['COUNT'])
limit_size = 5000
street_stride = np.arange(0, all_business_size, limit_size) #this will be used to page through the SF business address database with a given pagination chunk

df_all_sf_business_list = list()
for stride_num, stride_start in enumerate(street_stride):
    df_all_sf_business_stride = client.get(sf_business_API_key, limit = limit_size, offset = stride_start, order = "ttxid") #without specifying, this will only return 1000 results, need to augment explicitly 
    df_all_sf_business_list.append(pd.DataFrame(df_all_sf_business_stride))

# %%
print(all_business_size, len(df_all_sf_business_list), len(df_all_sf_business_list[1]))
df_all_sf_business_list = pd.concat(df_all_sf_business_list).reset_index() #concat list of DFs
# Out:
# 335506 68 5000

# %%
df_all_sf_business_list.head(2)
# Out:
#    index                uniqueid           ttxid certificate_number  \
# 0      0  0000024-02-999-0000024  0000024-02-999            0000024
# 1      1  0000028-02-001-0000028  0000028-02-001            0000028
#
#      ownership_name          dba_name full_business_address           city  \
# 0  Eastman Kodak Co  Eastman Kodak Co          343 State St      Rochester
# 1   Ferrando Louise  3101 Laguna Apts        3101 Laguna St  San Francisco
#
#   state business_zip  ...           data_loaded_at             dba_end_date  \
# 0    NY        14650  ...  2025-01-19T04:04:01.000                      NaN
# 1    CA        94123  ...  2025-01-19T04:04:01.000  2023-06-19T00:00:00.000
#
#          location_end_date supervisor_district  \
# 0                      NaN                 NaN
# 1  2023-06-19T00:00:00.000                   2
#
#   neighborhoods_analysis_boundaries business_corridor  lic  \
# 0                               NaN               NaN  NaN
# 1                            Marina               NaN  NaN
#
#   lic_code_description lic_code_descriptions_list  administratively_closed
# 0                  NaN                        NaN                      NaN
# 1                  NaN                        NaN                      NaN
#
# [2 rows x 33 columns]

# %% [markdown]
# # Parsing locations into addresses
#
# Some of the movie filming locations aren't clear addresses, they'll require some cleaning. I intend to use fuzzy address matching to align the records

# %%
all_unique_locations = list(df_movie_basic_info.loc[:, 'locations'].unique())
print('There are ' + str(len(all_unique_locations)) + ' unique locations listed in this dataframe. A sample of 10 values:')
pprint(all_unique_locations[0:10])
# Out:
# There are 1635 unique locations listed in this dataframe. A sample of 10 values:
# ['717 grant ave',
#  'filbert btwn powell and stockton',
#  'Empty',
#  'embarcadero street',
#  'fort baker',
#  'brannan btwn 3rd and 6th st',
#  '17th and arkansas',
#  'california & grant streets',
#  'california at grant ave',
#  '21st st at san carlos']

# %%
# collect all unique street names
all_unique_street_names = df_all_sf_address['street_name'].unique()  #for some reason this is NOT picking up the embarcadero 
print(f"Per OpenSF's database, there are {all_unique_street_names.shape[0]} unique street names in San Francisco.")
print(' 10 sample street names are: ', all_unique_street_names[0:10])
# Out:
# Per OpenSF's database, there are 1959 unique street names in San Francisco.
#  10 sample street names are:  ['alemany' 'balboa' 'bayview park' 'berry' 'burke' 'donahue' 'earl'
#  'edgehill' 'fitzgerald' 'gibson']

# %%
unique_street_names_in_movie_location = dict()
to_unique_street_match = list()

for i, movie_location in tqdm.tqdm(enumerate(all_unique_locations)):
    matches =[street_name.lower() for street_name in all_unique_street_names if street_name.lower() in movie_location.lower()]
    unique_street_names_in_movie_location[movie_location] = matches

key_indexes = list(unique_street_names_in_movie_location)[3]

print('sample matching street name is', unique_street_names_in_movie_location[key_indexes])
# Out:
# 1635it [00:00, 3315.79it/s]
# sample matching street name is ['embarcadero']

# %%
# create boolean for rows of ALL SF STREETS that on the unique street name that is a substring of the movie location

df_relevant_sf_address = dict() #create dict where KEY = movie location, VALUE = a DF containing all street addresses on Street of interest (SOI)

for i, movie_location in tqdm.tqdm(enumerate(unique_street_names_in_movie_location)):
    df_relevant_sf_address[movie_location] = [] #in case you had to skip 
    
    if unique_street_names_in_movie_location[movie_location] == []:
        continue

    street_is_substring_bool =  df_all_sf_address.loc[:, 'street_name'].isin(unique_street_names_in_movie_location[movie_location]) #this is list of rows that are in 
    df_relevant_sf_address[movie_location] =df_all_sf_address.loc[street_is_substring_bool, :]
# Out:
# 1635it [00:10, 155.95it/s]

# %%
movie_original_location_dict = dict()
#iterate through ALL movie locations 
unique_street_names_in_movie_location
for iter_num,iter_location in tqdm.tqdm(enumerate(df_movie_basic_info.loc[:,'locations'])):
    movie_original_location_dict[iter_location] = 'Empty'

    if np.logical_or(iter_location == 'Empty', type(df_relevant_sf_address[iter_location]) is list): #it will be a list if no matches for that street address exist
        continue
    
    list_of_choices = list(df_relevant_sf_address[iter_location].loc[:,'address'].values) #index the dict of Dfs to find the df of RELEVANT addresses, turn that into list of values for comparison

    sample_match_highest = process.extractOne(iter_location, list_of_choices, scorer = fuzz.token_sort_ratio) #can pass scorer for extract One
    movie_original_location_dict[iter_location] = sample_match_highest[0] #create key value pair where key is OLD LOCATION, value is NEW location
# Out:
# 2084it [00:05, 388.63it/s]

# %%
df_movie_location_fuzz_guess = pd.DataFrame(movie_original_location_dict.items(), columns = ['Input Name', 'Best Guess'])
df_movie_location_fuzz_guess
# Out:
#                                   Input Name           Best Guess
# 0                              717 grant ave        717 grant ave
# 1           filbert btwn powell and stockton     310 b filbert st
# 2                                      Empty                Empty
# 3                         embarcadero street    0 the embarcadero
# 4                                 fort baker           1 baker st
# ...                                      ...                  ...
# 1630               moscone convention center                Empty
# 1631                          2712 bryant st       2712 bryant st
# 1632                                  pier 1                Empty
# 1633                       100 alemany blvd.     100 alemany blvd
# 1634  montgomery between washington and bush  845 b montgomery st
#
# [1635 rows x 2 columns]

# %%
df_non_matched_locations = df_movie_location_fuzz_guess.loc[df_movie_location_fuzz_guess["Best Guess"] == "Empty", :]
df_non_matched_locations
# Out:
#                      Input Name Best Guess
# 2                         Empty      Empty
# 31                    city hall      Empty
# 86                   coit tower      Empty
# 92                  doc's clock      Empty
# 107             aub zam zam bar      Empty
# ...                         ...        ...
# 1594           pier 28, hi-dive      Empty
# 1600                   the stud      Empty
# 1611              antonio alley      Empty
# 1630  moscone convention center      Empty
# 1632                     pier 1      Empty
#
# [85 rows x 2 columns]

# %% [markdown]
# #### Compare unmatched locations to major landmarks

# %%
#list of choices will be the landmark wiki
df_non_matched_locations_guesses = dict()
#df_landmark_wiki.head()
list_of_choices = list(df_landmark_wiki.loc[:,'Landmark Name'].values) #index the dict of Dfs to find the df of RELEVANT addresses, turn that into list of values for comparison

for iter_num,iter_location in tqdm.tqdm(enumerate(df_non_matched_locations.loc[:,'Input Name'])):
    sample_match_highest = process.extractOne(iter_location, list_of_choices, scorer = fuzz.token_set_ratio) #can pass scorer for extract One
    df_non_matched_locations_guesses[iter_location]= sample_match_highest

df_non_matched_locations_guesses
# Out:
# 85it [00:00, 899.27it/s]
# {'Empty': ('stanyan house', 33),
#  'city hall': ('san francisco city hall', 100),
#  'coit tower': ('lillie hitchcock coit tower', 100),
#  "doc's clock": ('samuels clock', 62),
#  'aub zam zam bar': ("sam jordan's bar", 59),
#  'palace of fine arts': ('palace of fine arts', 100),
#  'real guitars': ('leale house', 52),
#  'pier 7': ('hibernia bank', 42),
#  'chrissy field': ('charles dietle house', 48),
#  'hamburger haven': ('chambers mansion', 58),
#  'pier 27': ('hibernia bank', 40),
#  'f train charter': ('chambers mansion', 58),
#  'barbary coast': ('jackson brewery complex', 50),
#  'epic roasthouse': ('fireboat house', 69),
#  'sf war memorial opera house': ('roos house', 67),
#  "mcdonald's restaurant (701 3rd street, soma)": ("jack's restaurant", 83),
#  '2 rowland': ('koshland house', 52),
#  'ferry building': ('ferry building', 100),
#  'pier 9, at autodesk': ('merryvale antiques', 44),
#  '145 9th st': ('st. charles school', 37),
#  'at&t stadium': ("jack's restaurant", 48),
#  'pier 43': ('hibernia bank', 40),
#  'pier 39': ('hibernia bank', 40),
#  'hall of justice': ('schubert hall', 57),
#  'alcatraz island': ('italian american bank', 50),
#  'tonic': ('tobin house', 38),
#  'tenderloin neighborhood': ('potrero hill neighborhood house', 69),
#  'the stud, 399 9th street': ('filbert street cottages (bush cottages and the school of basic design and color)',
#   61),
#  'sutro baths': ("james lick baths/people's laundry building", 62),
#  'st regis hotel, 125 3rd street': ('hotel utah', 67),
#  '168 2nd street, blue bottle coffee': ('howard/26th street cottages', 50),
#  '44 montogomery': ('fairmont hotel', 43),
#  'rowland street': ('ghirardelli annex-jackson street', 60),
#  'terry a. francois blvd.': ('san francisco eagle bar', 55),
#  'pier 41': ('hibernia bank', 40),
#  'pier 45': ('hibernia bank', 40),
#  'raw hide ii (280 seventh street)': ('ghirardelli annex-jackson street', 55),
#  'punjab': ('talbot–dutton house', 32),
#  'pier 45 - musee mechanique': ('richard e. queen house', 49),
#  'alamo square': ('ghirardelli square', 67),
#  'fort point': ('hunters point springs and albion brewery', 67),
#  'pier 14': ('hibernia bank', 40),
#  'the end up, 401 6th streeet': ('bush street temple (soto mission)', 49),
#  'pier 43 1/2': ('paper doll (bar)', 40),
#  "s.s. jeremiah o'brien": ('oriental warehouse', 56),
#  'claire lilienthal elementary school': ('haas-lilienthal house', 65),
#  '4704 3rd st': ('saint brigid church', 40),
#  'caffe trieste': ('clay theatre', 56),
#  'tonga room': ('palace hotel and garden court room', 57),
#  "gabbiano's restaurant (ferry building)": ('ferry building', 100),
#  'cow palace': ('palace hotel and garden court room', 75),
#  'antonio street': ('ghirardelli annex-jackson street', 60),
#  'pier 24': ('hibernia bank', 40),
#  'the barbary coast': ('castro theatre', 52),
#  '253 4th ave.': ('clay theatre', 43),
#  'eros': ('roos house', 57),
#  '"metzger\'s apt" 151 alice b. toklas pl.': ('alemany emergency hospital and health building',
#   44),
#  'mr. s leather': ('atherton house', 54),
#  '386 4th ave': ('clay theatre', 43),
#  "starbucks at 333 o'farrell st.": ('engine co. no. 37, truck co. no. 9', 46),
#  "jeremiah o'brien ship at pier 35": ('north end police station and garage',
#   48),
#  "willy's barber shop": ("archbishop's mansion", 56),
#  'piers 30-32': ('paper doll (bar)', 40),
#  '2930 3rd street': ('ghirardelli annex-jackson street', 57),
#  'kezar pavillion': ('new era hall', 52),
#  '145 barlett st.': ('haslett warehouse', 45),
#  'f train': ('trinity church', 48),
#  'pier 5': ('hibernia bank', 42),
#  'pier 50': ('hibernia bank', 40),
#  "orphan andy's": ("sam jordan's bar", 55),
#  'areas around transamerica building': ('transamerica building (old fugazi bank building)',
#   76),
#  'w hotel, trace bar - 181 3rd st.': ('hotel utah', 67),
#  'pier 96': ('hibernia bank', 40),
#  'the ramp restaurant': ("jack's restaurant", 74),
#  'the ferry building': ('ferry building', 100),
#  'wine impression': ('new mission theater', 53),
#  'ele nino traiing cetner, 2920 3rd street': ('clay street center/chinese historical society of america',
#   48),
#  'players arcade at pier 39': ('cable car barn and power house', 51),
#  'motel capri': ('gaylord hotel', 58),
#  'pier 50- end of the pier': ('house of the flag', 52),
#  'pier 28, hi-dive': ('hallidie building', 44),
#  'the stud': ('house of the flag', 55),
#  'antonio alley': ('washington square', 53),
#  'moscone convention center': ('mission cultural center for latino arts', 53),
#  'pier 1': ('hibernia bank', 42)}

# %% [markdown]
# because a lot of these guesses have a low similarity ratio (close to 50%), we threshold the ones below 90%

# %%
#threshold highest matching tokens to extrapolate, cuting 
for key_val in list(df_non_matched_locations_guesses.keys()):
    if int(df_non_matched_locations_guesses[key_val][1]) < 90: #if exceeds threshold 
        df_non_matched_locations_guesses.pop(key_val, None) #delete entry
    else:
        df_non_matched_locations_guesses[key_val] = df_non_matched_locations_guesses[key_val][0]

# %%
df_landmark_location_guess = pd.DataFrame(data = df_non_matched_locations_guesses.items(), columns = ['Input Name', 'Landmark Match'])
df_landmark_location_guess
# Out:
#                                Input Name               Landmark Match
# 0                               city hall      san francisco city hall
# 1                              coit tower  lillie hitchcock coit tower
# 2                     palace of fine arts          palace of fine arts
# 3                          ferry building               ferry building
# 4  gabbiano's restaurant (ferry building)               ferry building
# 5                      the ferry building               ferry building

# %%
for index, key in enumerate(df_non_matched_locations_guesses):
    print(index, key)
    df_non_matched_locations.loc[df_non_matched_locations['Input Name'] == key, 'Best Guess'] = df_non_matched_locations_guesses[key]
# Out:
# 0 city hall
# 1 coit tower
# 2 palace of fine arts
# 3 ferry building
# 4 gabbiano's restaurant (ferry building)
# 5 the ferry building

# %%
num_non_matched_locations = df_non_matched_locations.shape[0]
num_total_locations = len(unique_street_names_in_movie_location)
print( "Proportion of unmatched are ", round(num_non_matched_locations/num_total_locations, 2))
# Out:
# Proportion of unmatched are  0.05

# %% [markdown]
# Given a miss rate of about 5%, I'll continue with a preliminary mapping of the data. First though, I need to join the guesses with the original movie data.

# %%
df_movie_location_fuzz_guess.head(1)
# Out:
#       Input Name     Best Guess
# 0  717 grant ave  717 grant ave

# %%
df_movie_basic_info.head(1)
# Out:
#                 title release_year      locations
# 0  Always Be My Maybe         2019  717 grant ave

# %%
df_all_sf_address.head(1)
# Out:
#    index eas_baseid         address address_number street_name street_type  \
# 0      0     383793  0 alemany blvd              0     alemany        blvd
#
#   zip_code      cnn      longitude     latitude  \
# 0    94110  2156000  -122.41038038  37.73526758
#
#                                                point  \
# 0  {'type': 'Point', 'coordinates': [-122.4103803...
#
#                     supdist supdistpad numbertext           nhood  \
# 0  SUPERVISORIAL DISTRICT 9         09       NINE  Bernal Heights
#
#                 data_as_of           data_loaded_at address_number_suffix  \
# 0  2025-01-19T03:37:00.000  2025-01-19T10:04:00.630                   NaN
#
#   complete_landmark_name
# 0                    NaN

# %%
#join fuzzy guesses with the movie info
df_movies_best_guesses = df_movie_basic_info.merge(df_movie_location_fuzz_guess, how = 'left', left_on = 'locations', right_on = 'Input Name')

# %%
#now join movie guesses with address info
df_movies_full_address = df_movies_best_guesses.merge(df_all_sf_address, how = 'left', left_on = 'Best Guess', right_on = 'address')
df_movies_full_address
# Out:
#                          title release_year  \
# 0           Always Be My Maybe         2019
# 1                         DEVS         2020
# 2               Faces of Death         1978
# 3               Romeo Must Die         2000
# 4                  San Andreas         2015
# ...                        ...          ...
# 2080           Women is Losers         2020
# 2081                  Godzilla         2014
# 2082                Cardinal X         2015
# 2083  The Matrix Resurrections         2021
# 2084    24 Hours on Craigslist         2005
#
#                                    locations  \
# 0                              717 grant ave
# 1           filbert btwn powell and stockton
# 2                                      Empty
# 3                         embarcadero street
# 4                                 fort baker
# ...                                      ...
# 2080                          2712 bryant st
# 2081                                  pier 1
# 2082                       100 alemany blvd.
# 2083  montgomery between washington and bush
# 2084                                   Empty
#
#                                   Input Name           Best Guess   index  \
# 0                              717 grant ave        717 grant ave  3549.0
# 1           filbert btwn powell and stockton     310 b filbert st   460.0
# 2                                      Empty                Empty     NaN
# 3                         embarcadero street    0 the embarcadero    21.0
# 4                                 fort baker           1 baker st  4062.0
# ...                                      ...                  ...     ...
# 2080                          2712 bryant st       2712 bryant st  2055.0
# 2081                                  pier 1                Empty     NaN
# 2082                       100 alemany blvd.     100 alemany blvd   546.0
# 2083  montgomery between washington and bush  845 b montgomery st  3039.0
# 2084                                   Empty                Empty     NaN
#
#      eas_baseid              address address_number  street_name  ...  \
# 0        280307        717 grant ave            717        grant  ...
# 1        447288     310 b filbert st            310      filbert  ...
# 2           NaN                  NaN            NaN          NaN  ...
# 3        481023    0 the embarcadero              0  embarcadero  ...
# 4        298036           1 baker st              1        baker  ...
# ...         ...                  ...            ...          ...  ...
# 2080     370911       2712 bryant st           2712       bryant  ...
# 2081        NaN                  NaN            NaN          NaN  ...
# 2082     495728     100 alemany blvd            100      alemany  ...
# 2083     477292  845 b montgomery st            845   montgomery  ...
# 2084        NaN                  NaN            NaN          NaN  ...
#
#          latitude                                              point  \
# 0     37.79364769  {'type': 'Point', 'coordinates': [-122.4063637...
# 1     37.80218768  {'type': 'Point', 'coordinates': [-122.4051148...
# 2             NaN                                                NaN
# 3     37.78812404  {'type': 'Point', 'coordinates': [-122.3863637...
# 4     37.77107289  {'type': 'Point', 'coordinates': [-122.4407537...
# ...           ...                                                ...
# 2080  37.75088102  {'type': 'Point', 'coordinates': [-122.4092658...
# 2081          NaN                                                NaN
# 2082  37.73684541  {'type': 'Point', 'coordinates': [-122.4089927...
# 2083  37.79691392  {'type': 'Point', 'coordinates': [-122.4039005...
# 2084          NaN                                                NaN
#
#                        supdist supdistpad numbertext  \
# 0     SUPERVISORIAL DISTRICT 3         03      THREE
# 1     SUPERVISORIAL DISTRICT 3         03      THREE
# 2                          NaN        NaN        NaN
# 3     SUPERVISORIAL DISTRICT 6         06        SIX
# 4     SUPERVISORIAL DISTRICT 5         05       FIVE
# ...                        ...        ...        ...
# 2080  SUPERVISORIAL DISTRICT 9         09       NINE
# 2081                       NaN        NaN        NaN
# 2082  SUPERVISORIAL DISTRICT 9         09       NINE
# 2083  SUPERVISORIAL DISTRICT 3         03      THREE
# 2084                       NaN        NaN        NaN
#
#                                nhood               data_as_of  \
# 0                          Chinatown  2025-01-19T03:36:00.000
# 1                        North Beach  2025-01-19T03:38:00.000
# 2                                NaN                      NaN
# 3     Financial District/South Beach  2025-01-19T03:38:00.000
# 4                     Haight Ashbury  2025-01-19T03:36:00.000
# ...                              ...                      ...
# 2080                         Mission  2025-01-19T03:37:00.000
# 2081                             NaN                      NaN
# 2082                  Bernal Heights  2025-01-19T03:39:00.000
# 2083                       Chinatown  2025-01-19T03:38:00.000
# 2084                             NaN                      NaN
#
#                data_loaded_at address_number_suffix complete_landmark_name
# 0     2025-01-19T10:04:00.630                   NaN                    NaN
# 1     2025-01-19T10:04:00.630                     B                    NaN
# 2                         NaN                   NaN                    NaN
# 3     2025-01-19T10:04:00.630                   NaN                    NaN
# 4     2025-01-19T10:04:00.630                   NaN                    NaN
# ...                       ...                   ...                    ...
# 2080  2025-01-19T10:04:00.630                   NaN                    NaN
# 2081                      NaN                   NaN                    NaN
# 2082  2025-01-19T10:04:00.630                   NaN                    NaN
# 2083  2025-01-19T10:04:00.630                     B                    NaN
# 2084                      NaN                   NaN                    NaN
#
# [2085 rows x 24 columns]

# %% [markdown]
# #### save csv

# %%
file_name = f"Movie Location Dataframe w Guess.csv"
df_movies_full_address.to_csv(file_name)

# %% [markdown]
# # Data Mapping:

# %% [markdown]
# ### Plotly Pass:
# I will use Plotly express,a high level API to access plotly functions

# %%
import plotly.express as px
import folium
from folium.plugins import MarkerCluster
#format for accessing an address lat and lon from the OG address book: df_all_sf_address.loc[1,'point']['coordinates']
df_movies_full_address.head(3)
# Out:
#                 title release_year                         locations  \
# 0  Always Be My Maybe         2019                     717 grant ave
# 1                DEVS         2020  filbert btwn powell and stockton
# 2      Faces of Death         1978                             Empty
#
#                          Input Name        Best Guess   index eas_baseid  \
# 0                     717 grant ave     717 grant ave  3549.0     280307
# 1  filbert btwn powell and stockton  310 b filbert st   460.0     447288
# 2                             Empty             Empty     NaN        NaN
#
#             address address_number street_name  ...     latitude  \
# 0     717 grant ave            717       grant  ...  37.79364769
# 1  310 b filbert st            310     filbert  ...  37.80218768
# 2               NaN            NaN         NaN  ...          NaN
#
#                                                point  \
# 0  {'type': 'Point', 'coordinates': [-122.4063637...
# 1  {'type': 'Point', 'coordinates': [-122.4051148...
# 2                                                NaN
#
#                     supdist supdistpad numbertext        nhood  \
# 0  SUPERVISORIAL DISTRICT 3         03      THREE    Chinatown
# 1  SUPERVISORIAL DISTRICT 3         03      THREE  North Beach
# 2                       NaN        NaN        NaN          NaN
#
#                 data_as_of           data_loaded_at address_number_suffix  \
# 0  2025-01-19T03:36:00.000  2025-01-19T10:04:00.630                   NaN
# 1  2025-01-19T03:38:00.000  2025-01-19T10:04:00.630                     B
# 2                      NaN                      NaN                   NaN
#
#   complete_landmark_name
# 0                    NaN
# 1                    NaN
# 2                    NaN
#
# [3 rows x 24 columns]

# %%
#import stored API key to access mapbox
with open('mapbox_token.txt', 'r') as f:
    mapbox_key = f.read().strip()
with open('omdb_api_key.txt', 'r') as omdb:
    omdb_key = omdb.read().strip()

# %%
#testing plotting scatterplot
df_movies_full_address.loc[:, ['longitude', 'latitude']] = df_movies_full_address.loc[:, ['longitude', 'latitude']].astype(float)
df_movies_full_address['release_year'] = df_movies_full_address['release_year'].astype(int)
df_movies_full_address['release_decade'] =np.floor(df_movies_full_address['release_year']/10)*10
df_movies_full_address['release_decade'] = df_movies_full_address['release_decade'].astype(int)
df_movies_full_address['nhood'] = df_movies_full_address['nhood'].astype(str)
df_movies_full_address.head(2)
# Out:
#                 title  release_year                         locations  \
# 0  Always Be My Maybe          2019                     717 grant ave
# 1                DEVS          2020  filbert btwn powell and stockton
#
#                          Input Name        Best Guess   index eas_baseid  \
# 0                     717 grant ave     717 grant ave  3549.0     280307
# 1  filbert btwn powell and stockton  310 b filbert st   460.0     447288
#
#             address address_number street_name  ...  \
# 0     717 grant ave            717       grant  ...
# 1  310 b filbert st            310     filbert  ...
#
#                                                point  \
# 0  {'type': 'Point', 'coordinates': [-122.4063637...
# 1  {'type': 'Point', 'coordinates': [-122.4051148...
#
#                     supdist supdistpad numbertext        nhood  \
# 0  SUPERVISORIAL DISTRICT 3         03      THREE    Chinatown
# 1  SUPERVISORIAL DISTRICT 3         03      THREE  North Beach
#
#                 data_as_of           data_loaded_at address_number_suffix  \
# 0  2025-01-19T03:36:00.000  2025-01-19T10:04:00.630                   NaN
# 1  2025-01-19T03:38:00.000  2025-01-19T10:04:00.630                     B
#
#   complete_landmark_name release_decade
# 0                    NaN           2010
# 1                    NaN           2020
#
# [2 rows x 25 columns]

# %%
sorted_year_list = np.sort(df_movies_full_address['release_year'].unique())
sorted_year_list
sorted_decade_list = np.sort(df_movies_full_address['release_decade'].unique())

# %%
df = px.data.carshare()
fig = px.scatter_map(df, lat="centroid_lat", lon="centroid_lon",     color="peak_hour", size="car_hours",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=10)

# %%
#https://plotly.com/python/plotly-express/
#https://medium.com/codex/bring-your-boring-plots-to-life-by-animating-them-acbb8b4b5388
#https://www.visualnoise.io/interactive-maps-with-python-pandas-and-plotly/
#https://plotly.com/python/scattermapbox/

px.set_mapbox_access_token(mapbox_key)
fig = px.scatter_map(df_movies_full_address, lon = "longitude", lat = "latitude",
                        zoom = 11, hover_name = 'title', hover_data = ['address', 'release_year'],
                        color = "release_decade", color_continuous_scale= 'jet'
                        , height = 600, width= 1000
                        )
fig.update_traces(marker=dict(size=5,  opacity = 0.4))
fig.update_layout(mapbox_style = 'basic')

#animation_frame='release_year', category_orders = {'release_year':sorted_year_list}

# %%
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")
fig.show()
# Out:
# <div>                            <div id="dd080efa-3364-49b9-947d-e8b04e7caec0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd080efa-3364-49b9-947d-e8b04e7caec0")) {                    Plotly.newPlot(                        "dd080efa-3364-49b9-947d-e8b04e7caec0",                        [{"hovertemplate":"species=setosa\u003cbr\u003esepal_width=%{x}\u003cbr\u003esepal_length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"setosa","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"setosa","orientation":"v","showlegend":true,"x":[3.5,3.0,3.2,3.1,3.6,3.9,3.4,3.4,2.9,3.1,3.7,3.4,3.0,3.0,4.0,4.4,3.9,3.5,3.8,3.8,3.4,3.7,3.6,3.3,3.4,3.0,3.4,3.5,3.4,3.2,3.1,3.4,4.1,4.2,3.1,3.2,3.5,3.1,3.0,3.4,3.5,2.3,3.2,3.5,3.8,3.0,3.8,3.2,3.7,3.3],"xaxis":"x","y":[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9,5.4,4.8,4.8,4.3,5.8,5.7,5.4,5.1,5.7,5.1,5.4,5.1,4.6,5.1,4.8,5.0,5.0,5.2,5.2,4.7,4.8,5.4,5.2,5.5,4.9,5.0,5.5,4.9,4.4,5.1,5.0,4.5,4.4,5.0,5.1,4.8,5.1,4.6,5.3,5.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"species=versicolor\u003cbr\u003esepal_width=%{x}\u003cbr\u003esepal_length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"versicolor","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"versicolor","orientation":"v","showlegend":true,"x":[3.2,3.2,3.1,2.3,2.8,2.8,3.3,2.4,2.9,2.7,2.0,3.0,2.2,2.9,2.9,3.1,3.0,2.7,2.2,2.5,3.2,2.8,2.5,2.8,2.9,3.0,2.8,3.0,2.9,2.6,2.4,2.4,2.7,2.7,3.0,3.4,3.1,2.3,3.0,2.5,2.6,3.0,2.6,2.3,2.7,3.0,2.9,2.9,2.5,2.8],"xaxis":"x","y":[7.0,6.4,6.9,5.5,6.5,5.7,6.3,4.9,6.6,5.2,5.0,5.9,6.0,6.1,5.6,6.7,5.6,5.8,6.2,5.6,5.9,6.1,6.3,6.1,6.4,6.6,6.8,6.7,6.0,5.7,5.5,5.5,5.8,6.0,5.4,6.0,6.7,6.3,5.6,5.5,5.5,6.1,5.8,5.0,5.6,5.7,5.7,6.2,5.1,5.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"species=virginica\u003cbr\u003esepal_width=%{x}\u003cbr\u003esepal_length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"virginica","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"virginica","orientation":"v","showlegend":true,"x":[3.3,2.7,3.0,2.9,3.0,3.0,2.5,2.9,2.5,3.6,3.2,2.7,3.0,2.5,2.8,3.2,3.0,3.8,2.6,2.2,3.2,2.8,2.8,2.7,3.3,3.2,2.8,3.0,2.8,3.0,2.8,3.8,2.8,2.8,2.6,3.0,3.4,3.1,3.0,3.1,3.1,3.1,2.7,3.2,3.3,3.0,2.5,3.0,3.4,3.0],"xaxis":"x","y":[6.3,5.8,7.1,6.3,6.5,7.6,4.9,7.3,6.7,7.2,6.5,6.4,6.8,5.7,5.8,6.4,6.5,7.7,7.7,6.0,6.9,5.6,7.7,6.3,6.7,7.2,6.2,6.1,6.4,7.2,7.4,7.9,6.4,6.3,6.1,7.7,6.3,6.4,6.0,6.9,6.7,6.9,5.8,6.8,6.7,6.7,6.3,6.5,6.2,5.9],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapg ...

# %% [markdown]
# ### Import IMDB data to better sort datapoints
# Going to be using the cinemagoer package (available at cinemagoer.github.io)

# %%
#IMPORT IMDB datasets from https://cinemagoer.github.io/
movie_db = Cinemagoer()

#create df of movie information
all_movie_titles = df_movies_full_address['title'].unique().astype(list)
movie_years = df_movies_full_address.groupby('title')['release_year'].first().reset_index()

movie_years #seems a lot smaller than the full DF, investigate why
# Out:
#                       title  release_year
# 0                       180          2011
# 1    24 Hours on Craigslist          2005
# 2     40 Days and 40 Nights          2002
# 3                  48 Hours          1982
# 4            50 First Dates          2004
# ..                      ...           ...
# 331            Woman on Top          2000
# 332        Woman on the Run          1950
# 333         Women is Losers          2020
# 334    Yours, Mine and Ours          1968
# 335                  Zodiac          2007
#
# [336 rows x 2 columns]

# %%
df_count_film_locations = df_movies_full_address.groupby('title')['release_year'].count().reset_index()
fig = plt.figure()
ax = fig.subplots()
df_count_film_locations.hist(ax = ax);
ax.set(title = "# of locations used per feature");

# %%
#use OMDB requests- 1000 requests per day https://www.omdbapi.com/
#OMDB api key is omdb_key

limit_request = 999

omdb_url =  f'http://www.omdbapi.com/?apikey={omdb_key}'
#set current query values and params
query_movie_year = movie_years.loc[111, 'release_year']
query_movie_title =movie_years.loc[111, 'title']
params = {"t": query_movie_title, "y":query_movie_year, "plot": 'full'}
params
# Out:
# {'t': 'Getting Even with Dad', 'y': 1994, 'plot': 'full'}

# %%
#run current API request 
# omdb_movie_search = requests.get(omdb_url, params = params).json()
# omdb_movie_search.update({'release_year':query_movie_year, 'searched_title' : query_movie_title}) #add key value pairs that are the search terms used 
# omdb_request_list.append(omdb_movie_search)

# %%
movie_years
# Out:
#                       title  release_year
# 0                       180          2011
# 1    24 Hours on Craigslist          2005
# 2     40 Days and 40 Nights          2002
# 3                  48 Hours          1982
# 4            50 First Dates          2004
# ..                      ...           ...
# 331            Woman on Top          2000
# 332        Woman on the Run          1950
# 333         Women is Losers          2020
# 334    Yours, Mine and Ours          1968
# 335                  Zodiac          2007
#
# [336 rows x 2 columns]

# %%
#1.5 min for full loop ## FOR loop for OMDB request
omdb_request_list = list()
#use itertuples to iterate over rows of movie_years dataframe
for row in movie_years.itertuples(name = None):
    query_movie_year = row[2]
    query_movie_title =row[1]    
    params = {"t": query_movie_title, "y":query_movie_year, "plot": 'full'}
    #run current API request 
    omdb_movie_search = requests.get(omdb_url, params = params).json()
    omdb_movie_search.update({'release_year':query_movie_year, 'searched_title' : query_movie_title}) #add key value pairs that are the search terms used 
    omdb_request_list.append(omdb_movie_search)

# %%
df_omdb_info = pd.DataFrame(omdb_request_list)
df_omdb_info #some rows are nan
# Out:
#                       Title  Year     Rated     Released  Runtime  \
# 0                       180  2011       N/A  24 Jun 2011  121 min
# 1    24 Hours on Craigslist  2005       N/A  07 Oct 2005   82 min
# 2     40 Days and 40 Nights  2002         R  01 Mar 2002   96 min
# 3                       NaN   NaN       NaN          NaN      NaN
# 4            50 First Dates  2004     PG-13  13 Feb 2004   99 min
# ..                      ...   ...       ...          ...      ...
# 331            Woman on Top  2000         R  22 Sep 2000   92 min
# 332        Woman on the Run  1950  Approved  04 Feb 1951   77 min
# 333                     NaN   NaN       NaN          NaN      NaN
# 334    Yours, Mine and Ours  1968   Unrated  24 Apr 1968  111 min
# 335                  Zodiac  2007         R  02 Mar 2007  157 min
#
#                               Genre               Director  \
# 0                    Drama, Romance               Jayendra
# 1    Documentary, Biography, Comedy  Michael Ferris Gibson
# 2                   Comedy, Romance        Michael Lehmann
# 3                               NaN                    NaN
# 4            Comedy, Drama, Romance            Peter Segal
# ..                              ...                    ...
# 331        Comedy, Fantasy, Romance            Fina Torres
# 332         Crime, Drama, Film-Noir          Norman Foster
# 333                             NaN                    NaN
# 334                  Comedy, Family     Melville Shavelson
# 335           Crime, Drama, Mystery          David Fincher
#
#                                               Writer  \
# 0       Umarji Anuradha, A.N. Balakrishnan, Jayendra
# 1                                                N/A
# 2                                          Rob Perez
# 3                                                NaN
# 4                                        George Wing
# ..                                               ...
# 331                                       Vera Blasi
# 332        Alan Campbell, Norman Foster, Sylvia Tate
# 333                                              NaN
# 334  Melville Shavelson, Mort Lachman, Madelyn Davis
# 335               James Vanderbilt, Robert Graysmith
#
#                                                Actors  \
# 0                Siddharth, Nithya Menen, Priya Anand
# 1            Rachel Berney, Mike Curtis, Holly Dalton
# 2     Josh Hartnett, Shannyn Sossamon, Paulo Costanzo
# 3                                                 NaN
# 4         Adam Sandler, Drew Barrymore, Rob Schneider
# ..                                                ...
# 331   Penélope Cruz, Murilo Benício, Harold Perrineau
# 332        Ann Sheridan, Dennis O'Keefe, Robert Keith
# 333                                               NaN
# 334            Lucille Ball, Henry Fonda, Van Johnson
# 335  Jake Gyllenhaal, Robert Downey Jr., Mark Ruffalo
#
#                                                   Plot  ...   Type  DVD  \
# 0    An inquisitive girl, Vidya falls in love with ...  ...  movie  N/A
# 1    This is about Craig Newmark popular classified...  ...  movie  N/A
# 2    Nicole broke up with Matt months ago and is no...  ...  movie  N/A
# 3                                                  NaN  ...    NaN  NaN
# 4    Henry Roth lives in a Hawaiian paradise with t...  ...  movie  N/A
# ..                                                 ...  ...    ...  ...
# 331  Plagued by chronic motion sickness, Isabella--...  ...  movie  N/A
# 332  Frank Johnson (Ross Elliott), sole witness to ...  ...  movie  N/A
# 333                                                NaN  ...    NaN  NaN
# 334  When a widower with 10 children marries a wido...  ...  movie  N/A
# 335  A serial killer in the San Francisco Bay Area ...  ...  movie  N/A
#
#         BoxOffice Production Website Response release_year  \
# 0             N/A        N/A     N/A     True         2011
# 1             N/A        N/A     N/A     True         2005
# 2     $37,950,822        N/A     N/A     True         2002
# 3             NaN        NaN     NaN    False         1982
# 4    $120,908,074        N/A     N/A     True         2004
# ..            ...        ...     ...      ...          ...
# 331    $5,020,111        N/A     N/A     True         2000
# 332           N/A        N/A     N/A     True         1950
# 333           NaN        NaN     NaN    False         2020
# 334           N/A        N/A     N/A     True         1968
# 335   $33,080,084        N/A     N/A     True         2007
#
#              searched_title             Error totalSeasons
# 0                       180               NaN          NaN
# 1    24 Hours on Craigslist               NaN          NaN
# 2     40 Days and 40 Nights               NaN          NaN
# 3                  48 Hours  Movie not found!          NaN
# 4            50 First Dates               NaN          NaN
# ..                      ...               ...          ...
# 331            Woman on Top               NaN          NaN
# 332        Woman on the Run               NaN          NaN
# 333         Women is Losers  Movie not found!          NaN
# 334    Yours, Mine and Ours               NaN          NaN
# 335                  Zodiac               NaN          NaN
#
# [336 rows x 29 columns]

# %%
#replace N/A with npnan
df_omdb_info.replace("N/A", value = np.nan, inplace = True)

# %%
#check how many entries are nan
print(f"{sum(df_omdb_info.Title.isna().values)} productions were unable to be found in OMDB")
# Out:
# 57 productions were unable to be found in OMDB

# %%
df_omdb_info= df_omdb_info.dropna(subset = ["Title"] ).reset_index()
df_omdb_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           279 non-null    int64
#  1   Title           279 non-null    object
#  2   Year            279 non-null    object
#  3   Rated           261 non-null    object
#  4   Released        276 non-null    object
#  5   Runtime         272 non-null    object
#  6   Genre           278 non-null    object
#  7   Director        264 non-null    object
#  8   Writer          274 non-null    object
#  9   Actors          279 non-null    object
#  10  Plot            279 non-null    object
#  11  Language        279 non-null    object
#  12  Country         278 non-null    object
#  13  Awards          234 non-null    object
#  14  Poster          276 non-null    object
#  15  Ratings         279 non-null    object
#  16  Metascore       183 non-null    object
#  17  imdbRating      277 non-null    object
#  18  imdbVotes       277 non-null    object
#  19  imdbID          279 non-null    object
#  20  Type            279 non-null    object
#  21  DVD             3 non-null      object
#  22  BoxOffice       189 non-null    object
#  23  Production      1 non-null      object
#  24  Website         0 non-null      float64
#  25  Response        279 non-null    object
#  26  release_year    279 non-null    int64
#  27  searched_title  279 non-null    object
#  28  Error           0 non-null      object
#  29  totalSeasons    14 non-null     object
# dtypes: float64(1), int64(2), object(27)
# memory usage: 65.5+ KB

# %%
df_omdb_info= df_omdb_info.astype({"imdbRating": "float"})
df_omdb_info.loc[:,[ "imdbVotes", "imdbRating", "Metascore"]]
# Out:
#     imdbVotes  imdbRating Metascore
# 0         877         6.2       NaN
# 1         218         5.3        47
# 2      76,728         5.6        53
# 3     392,824         6.8        48
# 4       1,464         5.9       NaN
# ..        ...         ...       ...
# 274    23,956         6.6       NaN
# 275    11,032         5.3        41
# 276     4,980         7.2       NaN
# 277    10,069         7.1       NaN
# 278   624,988         7.7        79
#
# [279 rows x 3 columns]

# %%
#idea- use imdbscore as thresholding for what to include in LLM prompt
fig = plt.figure()
ax = fig.subplots()
df_omdb_info.hist(column = 'imdbRating', ax = ax, bins = 25);
ax.set(title = "# imdb ratings per feature");

# %%
#download film info database
filename = f'dataframe_omdb_info.csv'
df_omdb_info.to_csv(filename)

# %%
df_omdb_info['Genre'].unique()
# Out:
# array(['Drama, Romance', 'Documentary, Biography, Comedy',
#        'Comedy, Romance', 'Comedy, Drama, Romance', 'Short, Comedy',
#        'Action, Adventure, Thriller', 'Comedy, Crime, Mystery',
#        'Drama, Fantasy, Romance', 'Action, Crime, Drama',
#        'Drama, Music, Musical', 'Short, Drama', 'Drama', 'Comedy, Drama',
#        'Drama, Thriller', 'Short, Drama, War', 'Action, Comedy, Sci-Fi',
#        'Action, Adventure, Comedy', 'Adventure, Comedy, Horror',
#        'Documentary', 'Adventure, Drama, Romance',
#        'Drama, Mystery, Thriller', 'Comedy, Drama, Music',
#        'Biography, Drama', 'Comedy, Fantasy', 'Drama, Family',
#        'Drama, Romance, Sci-Fi', 'Biography, Crime, Drama',
#        'Action, Biography, Drama', 'Comedy, Crime, Drama',
#        'Action, Crime, Thriller', 'Comedy, Crime',
#        'Crime, Drama, Romance', 'Biography, Comedy, Musical',
#        'Drama, Mystery', 'Reality-TV', 'Comedy, Drama, Mystery', 'Comedy',
#        'Crime, Drama, Mystery', 'Documentary, Biography, History',
#        'Adventure, Comedy, Crime', 'Drama, Mystery, Sci-Fi',
#        'Film-Noir, Thriller', 'Action, Adventure, Drama',
#        'Comedy, Family, Fantasy', 'Romance, Comedy, Drama',
#        'Crime, Mystery, Thriller', 'Documentary, Horror',
#        'Biography, Drama, History', 'Comedy, Musical, Romance',
#        'Comedy, Family, Sci-Fi', 'Comedy, Mystery, Thriller',
#        'Action, Comedy, Crime', 'Biography, Drama, Romance',
#        'Comedy, Crime, Family', 'Action, Adventure, Sci-Fi', nan,
#        'Drama, Thriller, Western', 'Drama, Music', 'Comedy, Sport',
#        'Comedy, Drama, Fantasy', 'Musical', 'Adventure, Comedy, Family',
#        'Crime, Drama', 'Action, Sci-Fi', 'Action, Adventure',
#        'Drama, Fantasy, Horror', 'Horror, Sci-Fi',
#        'Crime, Drama, Thriller', 'Animation, Adventure, Family',
#        'Comedy, Romance, Sci-Fi', 'Action, Crime, Mystery', 'Sci-Fi',
#        'Drama, Film-Noir', 'Drama, Musical, Romance', 'Adventure',
#        'Biography, Comedy, Drama', 'Crime, Drama, Horror',
#        'Action, Sci-Fi, Sport', 'Drama, Music, Romance', 'Romance',
#        'Action, Adventure, Fantasy', 'Comedy, Family, Music',
#        'Mystery, Sci-Fi, Thriller', 'Adventure, Comedy, Sci-Fi',
#        'Horror, Mystery', 'Comedy, Fantasy, Romance',
#        'Drama, Horror, Mystery', 'Documentary, Drama', 'Drama, War',
#        'Drama, Romance, Music', 'Biography, Drama, Music',
#        'Action, Drama, Sport', 'Crime, Drama, Film-Noir',
#        'Crime, Film-Noir, Mystery', 'Drama, History',
#        'Animation, Family, Fantasy', 'Adventure, Comedy, Drama',
#        'Comedy, Family, Romance', 'Adventure, Biography, Drama',
#        'Adventure, Drama, Family', 'Action, Drama, Thriller',
#        'Adventure, Drama, Sci-Fi', 'Crime, Film-Noir, Thriller',
#        'Action, Drama, Sci-Fi', 'Action, Sci-Fi, Thriller',
#        'Mystery, Romance, Thriller', 'Comedy, Family'], dtype=object)

# %% [markdown]
# #### MAP: Using open source maps to plot points on the map
# https://towardsdatascience.com/pythons-geocoding-convert-a-list-of-addresses-into-a-map-f522ef513fd6

# %%
#use LLM to synthesize a composite movie 

#instead of movie poster GAN, use DALL-E to create posters
# https://openai.com/blog/dall-e-now-available-without-waitlist/

# %%
##WIP: movie poster GAN
"""
https://www.omdbapi.com/ #has a poster API, 1000 api pull .
https://imdb-api.com/api # 100 api request/day
https://developers.themoviedb.org/3/getting-started/introduction #no rate limit stated 

#IDEA, make a GAN that creates FAKE MOVIE POSTERS FOR A REGION????? #is there enough input data 
https://www.johnkraszewski.com/media-synthesis
https://www.kaggle.com/neha1703/movie-genre-from-its-poster/version/3
https://github.com/benckx/dnn-movie-posters
https://github.com/siddtheshah/poster-gan"""
# Out:
# '\nhttps://www.omdbapi.com/ #has a poster API, 1000 api pull .\nhttps://imdb-api.com/api # 100 api request/day\nhttps://developers.themoviedb.org/3/getting-started/introduction #no rate limit stated \n\n#IDEA, make a GAN that creates FAKE MOVIE POSTERS FOR A REGION????? #is there enough input data \nhttps://www.johnkraszewski.com/media-synthesis\nhttps://www.kaggle.com/neha1703/movie-genre-from-its-poster/version/3\nhttps://github.com/benckx/dnn-movie-posters\nhttps://github.com/siddtheshah/poster-gan'

# %% [markdown]
# ## Collect data by neighborhood

# %%
df_movies_full_address.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2085 entries, 0 to 2084
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   2085 non-null   object
#  1   release_year            2085 non-null   int32
#  2   locations               2085 non-null   object
#  3   Input Name              2085 non-null   object
#  4   Best Guess              2085 non-null   object
#  5   index                   1877 non-null   float64
#  6   eas_baseid              1877 non-null   object
#  7   address                 1877 non-null   object
#  8   address_number          1877 non-null   object
#  9   street_name             1877 non-null   object
#  10  street_type             1787 non-null   object
#  11  zip_code                1877 non-null   object
#  12  cnn                     1877 non-null   object
#  13  longitude               1877 non-null   object
#  14  latitude                1877 non-null   object
#  15  point                   1877 non-null   object
#  16  supdist                 1877 non-null   object
#  17  supdistpad              1877 non-null   object
#  18  numbertext              1877 non-null   object
#  19  nhood                   2085 non-null   object
#  20  data_as_of              1877 non-null   object
#  21  data_loaded_at          1877 non-null   object
#  22  address_number_suffix   682 non-null    object
#  23  complete_landmark_name  21 non-null     object
#  24  release_decade          2085 non-null   int32
# dtypes: float64(1), int32(2), object(22)
# memory usage: 391.1+ KB

# %%
df_total_films_by_nhood = df_movies_full_address.nhood.value_counts().to_frame().reset_index()
df_total_films_by_nhood
# Out:
#                              nhood  count
# 0   Financial District/South Beach    267
# 1                              nan    208
# 2                      North Beach    174
# 3                         Nob Hill    149
# 4                        Chinatown    146
# 5                          Mission    145
# 6                       Tenderloin    100
# 7              Castro/Upper Market     70
# 8                  South of Market     65
# 9                     Potrero Hill     65
# 10                    Hayes Valley     63
# 11                    Russian Hill     60
# 12                 Pacific Heights     55
# 13                          Marina     49
# 14                  Bernal Heights     46
# 15                  Haight Ashbury     46
# 16                      Noe Valley     35
# 17                       Excelsior     35
# 18                Western Addition     33
# 19           Bayview Hunters Point     31
# 20              West of Twin Peaks     29
# 21                 Treasure Island     25
# 22                        Presidio     22
# 23                  Outer Richmond     20
# 24                     Mission Bay     20
# 25      Oceanview/Merced/Ingleside     18
# 26                    Inner Sunset     15
# 27                      Twin Peaks     14
# 28                   Outer Mission     12
# 29                 Sunset/Parkside     10
# 30                        Seacliff     10
# 31               Lone Mountain/USF     10
# 32                Presidio Heights     10
# 33                  Inner Richmond      9
# 34                         Portola      6
# 35                Golden Gate Park      6
# 36                       Japantown      3
# 37                       Lakeshore      3
# 38                    Lincoln Park      1

# %%
df_movies_full_address.nhood.unique()
# Out:
# array(['Chinatown', 'North Beach', 'nan',
#        'Financial District/South Beach', 'Haight Ashbury', 'Potrero Hill',
#        'Treasure Island', 'Mission', 'Nob Hill', 'Western Addition',
#        'Hayes Valley', 'Mission Bay', 'Outer Mission', 'South of Market',
#        'Pacific Heights', 'Russian Hill', 'Castro/Upper Market', 'Marina',
#        'Excelsior', 'Tenderloin', 'Lone Mountain/USF', 'Outer Richmond',
#        'Bernal Heights', 'Noe Valley', 'Presidio Heights', 'Twin Peaks',
#        'West of Twin Peaks', 'Sunset/Parkside', 'Seacliff',
#        'Bayview Hunters Point', 'Inner Sunset', 'Presidio', 'Portola',
#        'Japantown', 'Oceanview/Merced/Ingleside', 'Inner Richmond',
#        'Golden Gate Park', 'Lincoln Park', 'Lakeshore'], dtype=object)

# %%
top_5_filming_nhood = df_movies_full_address.nhood.value_counts().head(5).to_frame().reset_index()
top_5_filming_nhood
# Out:
#                             nhood  count
# 0  Financial District/South Beach    267
# 1                             nan    208
# 2                     North Beach    174
# 3                        Nob Hill    149
# 4                       Chinatown    146

# %%
bot_5_filming_nhood =  df_movies_full_address.nhood.value_counts().tail(5).to_frame().reset_index()
bot_5_filming_nhood
# Out:
#               nhood  count
# 0           Portola      6
# 1  Golden Gate Park      6
# 2         Japantown      3
# 3         Lakeshore      3
# 4      Lincoln Park      1

# %%
#color by neighborhood
fig = px.scatter_mapbox(df_movies_full_address, lon = "longitude", lat = "latitude",
                        zoom = 11, hover_name = 'title', hover_data = ['address', 'nhood'],height = 600, width= 1000,
                        color = "nhood",)
fig.update_traces(marker=dict(size=5,  opacity = 0.4))
fig.update_layout(mapbox_style ='streets') #good styles- 'carto-darkmatter' 'stamen-terrain' 'stamen-toner'
fig.show()
# Out:
# <div>                            <div id="78e8b6f3-257e-4d52-9b20-816a9b3d70ab" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78e8b6f3-257e-4d52-9b20-816a9b3d70ab")) {                    Plotly.newPlot(                        "78e8b6f3-257e-4d52-9b20-816a9b3d70ab",                        [{"customdata":[["717 grant ave","Chinatown"],["4 columbus ave","Chinatown"],["1062 a washington st","Chinatown"],["738 a washington st","Chinatown"],["90 gold st","Chinatown"],["845 a montgomery st","Chinatown"],["261 columbus ave","Chinatown"],["255 columbus ave","Chinatown"],["26 saint louis aly","Chinatown"],["738 a washington st","Chinatown"],["631 grant ave","Chinatown"],["4 columbus ave","Chinatown"],["128 columbus ave","Chinatown"],["600 montgomery st","Chinatown"],["738 a washington st","Chinatown"],["4 columbus ave","Chinatown"],["772 commercial st","Chinatown"],["738 a washington st","Chinatown"],["1 waverly pl","Chinatown"],["845 a montgomery st","Chinatown"],["1080 a washington st","Chinatown"],["1062 a washington st","Chinatown"],["920 sacramento st","Chinatown"],["714 a pacific ave","Chinatown"],["738 a washington st","Chinatown"],["11 walter u lum pl","Chinatown"],["738 a washington st","Chinatown"],["56 gold st","Chinatown"],["531 a jackson st","Chinatown"],["531 a jackson st","Chinatown"],["1062 a washington st","Chinatown"],["738 a washington st","Chinatown"],["738 a washington st","Chinatown"],["1062 a washington st","Chinatown"],["600 montgomery st","Chinatown"],["8 ross aly","Chinatown"],["839 clay st","Chinatown"],["34 a spofford st","Chinatown"],["255 columbus ave","Chinatown"],["1021 grant ave","Chinatown"],["373 columbus ave","Chinatown"],["845 b montgomery st","Chinatown"],["1541 b powell st","Chinatown"],["17 jack kerouac aly","Chinatown"],["4 columbus ave","Chinatown"],["323 pacific ave","Chinatown"],["845 a montgomery st","Chinatown"],["555 columbus ave","Chinatown"],["845 a montgomery st","Chinatown"],["659 a merchant st","Chinatown"],["1062 a washington st","Chinatown"],["738 a washington st","Chinatown"],["715 a commercial st","Chinatown"],["845 e montgomery st","Chinatown"],["610 r jackson st","Chinatown"],["738 washington st","Chinatown"],["940 powell st","Chinatown"],["738 a washington st","Chinatown"],["766 vallejo st","Chinatown"],["845 a montgomery st","Chinatown"],["531 a jackson st","Chinatown"],["845 a montgomery st","Chinatown"],["301 battery st","Chinatown"],["738 a washington st","Chinatown"],["845 a montgomery st","Chinatown"],["1062 a washington st","Chinatown"],["4 columbus ave","Chinatown"],["1062 a washington st","Chinatown"],["1820 a mason st","Chinatown"],["738 a washington st","Chinatown"],["4 columbus ave","Chinatown"],["255 columbus ave","Chinatown"],["1062 a washington st","Chinatown"],["261 columbus ave","Chinatown"],["919 kearny st","Chinatown"],["633 vallejo st","Chinatown"],["600 montgomery st","Chinatown"],["714 a pacific ave","Chinatown"],["738 a washington st","Chinatown"],["8 ross aly","Chinatown"],["738 a washington st","Chinatown"],["845 e montgomery st","Chinatown"],["845 a montgomery st","Chinatown"],["738 a washington st","Chinatown"],["940 powell st","Chinatown"],["845 a montgomery st","Chinatown"],["1000 powell st","Chinatown"],["1126 grant ave","Chinatown"],["738 a washington st","Chinatown"],["845 a montgomery st","Chinatown"],["714 a pacific ave","Chinatown"],["845 e montgomery st","Chinatown"],["738 a washington st","Chinatown"],["845 a montgomery st","Chinatown"],["738 a washington st","Chinatown"],["261 columbus ave","Chinatown"],["1954 mason st","Chinatown"],["1133 grant ave","Chinatown"],["4 columbus ave","Chinatown"],["550 montgomery st","Chinatown"],["738 a washington st","Chinatown"],["1062 a washington st","Chinatown"],["73 ...

# %% [markdown]
# ## extract top 5 rated movies by neighrbhood

# %%
df_omdb_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           279 non-null    int64
#  1   Title           279 non-null    object
#  2   Year            279 non-null    object
#  3   Rated           261 non-null    object
#  4   Released        276 non-null    object
#  5   Runtime         272 non-null    object
#  6   Genre           278 non-null    object
#  7   Director        264 non-null    object
#  8   Writer          274 non-null    object
#  9   Actors          279 non-null    object
#  10  Plot            279 non-null    object
#  11  Language        279 non-null    object
#  12  Country         278 non-null    object
#  13  Awards          234 non-null    object
#  14  Poster          276 non-null    object
#  15  Ratings         279 non-null    object
#  16  Metascore       183 non-null    object
#  17  imdbRating      277 non-null    float64
#  18  imdbVotes       277 non-null    object
#  19  imdbID          279 non-null    object
#  20  Type            279 non-null    object
#  21  DVD             3 non-null      object
#  22  BoxOffice       189 non-null    object
#  23  Production      1 non-null      object
#  24  Website         0 non-null      float64
#  25  Response        279 non-null    object
#  26  release_year    279 non-null    int64
#  27  searched_title  279 non-null    object
#  28  Error           0 non-null      object
#  29  totalSeasons    14 non-null     object
# dtypes: float64(2), int64(2), object(26)
# memory usage: 65.5+ KB

# %%
#add ratings info back to orignal df 
omdb_col_to_keep = ["Title", "Year", "Genre", "Plot", "imdbRating", "release_year"]
df_omdb_nhood = pd.merge(df_omdb_info.loc[:, omdb_col_to_keep], df_movies_full_address.loc[:, ["title", "nhood"]], how = "left", left_on = ["Title"], right_on = ["title"])
df_omdb_nhood
# Out:
#                      Title  Year                    Genre  \
# 0                      180  2011           Drama, Romance
# 1                      180  2011           Drama, Romance
# 2                      180  2011           Drama, Romance
# 3                      180  2011           Drama, Romance
# 4                      180  2011           Drama, Romance
# ...                    ...   ...                      ...
# 1431      Woman on the Run  1950  Crime, Drama, Film-Noir
# 1432      Woman on the Run  1950  Crime, Drama, Film-Noir
# 1433      Woman on the Run  1950  Crime, Drama, Film-Noir
# 1434  Yours, Mine and Ours  1968           Comedy, Family
# 1435                Zodiac  2007    Crime, Drama, Mystery
#
#                                                    Plot  imdbRating  \
# 0     An inquisitive girl, Vidya falls in love with ...         6.2
# 1     An inquisitive girl, Vidya falls in love with ...         6.2
# 2     An inquisitive girl, Vidya falls in love with ...         6.2
# 3     An inquisitive girl, Vidya falls in love with ...         6.2
# 4     An inquisitive girl, Vidya falls in love with ...         6.2
# ...                                                 ...         ...
# 1431  Frank Johnson (Ross Elliott), sole witness to ...         7.2
# 1432  Frank Johnson (Ross Elliott), sole witness to ...         7.2
# 1433  Frank Johnson (Ross Elliott), sole witness to ...         7.2
# 1434  When a widower with 10 children marries a wido...         7.1
# 1435  A serial killer in the San Francisco Bay Area ...         7.7
#
#       release_year                 title                           nhood
# 0             2011                   180                    Russian Hill
# 1             2011                   180  Financial District/South Beach
# 2             2011                   180                  Bernal Heights
# 3             2011                   180                             nan
# 4             2011                   180  Financial District/South Beach
# ...            ...                   ...                             ...
# 1431          1950      Woman on the Run                        Nob Hill
# 1432          1950      Woman on the Run                      Twin Peaks
# 1433          1950      Woman on the Run                    Russian Hill
# 1434          1968  Yours, Mine and Ours                             nan
# 1435          2007                Zodiac                 South of Market
#
# [1436 rows x 8 columns]

# %%
#top 5 movies
df_omdb_nhood.sort_values(by = "imdbRating", ascending = False).groupby('nhood')[["imdbRating","title","nhood", "Genre"]].head(1)
# Out:
#       imdbRating                                title  \
# 395          8.8                         Forrest Gump
# 1217         8.7                           The Matrix
# 1391         8.3                              Vertigo
# 1400         8.3                              Vertigo
# 1399         8.3                              Vertigo
# 1398         8.3                              Vertigo
# 1396         8.3                              Vertigo
# 1395         8.3                              Vertigo
# 1393         8.3                              Vertigo
# 1390         8.3                              Vertigo
# 1388         8.3                              Vertigo
# 1387         8.3                              Vertigo
# 581          8.2                              Looking
# 578          8.2                              Looking
# 577          8.2                              Looking
# 580          8.2                              Looking
# 828          8.2                               Sense8
# 584          8.2                              Looking
# 586          8.2                              Looking
# 837          8.2                               Sense8
# 829          8.2                               Sense8
# 832          8.2                               Sense8
# 836          8.2                               Sense8
# 616          8.2                              Looking
# 615          8.2                              Looking
# 613          8.2                              Looking
# 607          8.2                              Looking
# 605          8.2                              Looking
# 590          8.2                              Looking
# 1271         8.0             The Pursuit of Happyness
# 469          8.0                                Greed
# 1273         7.8                      The Right Stuff
# 326          7.7                          Dirty Harry
# 1071         7.7                     The Conversation
# 306          7.6       Dawn of the Planet of the Apes
# 1173         7.3  The Last Black Man in San Francisco
# 737          6.9                              Petulia
# 398          6.8                            Foul Play
#
#                                nhood                        Genre
# 395                           Marina               Drama, Romance
# 1217                       Lakeshore               Action, Sci-Fi
# 1391                     North Beach   Mystery, Romance, Thriller
# 1400                 South of Market   Mystery, Romance, Thriller
# 1399                  Inner Richmond   Mystery, Romance, Thriller
# 1398  Financial District/South Beach   Mystery, Romance, Thriller
# 1396                        Nob Hill   Mystery, Romance, Thriller
# 1395                Western Addition   Mystery, Romance, Thriller
# 1393                    Hayes Valley   Mystery, Romance, Thriller
# 1390                       Chinatown   Mystery, Romance, Thriller
# 1388             Castro/Upper Market   Mystery, Romance, Thriller
# 1387                    Russian Hill   Mystery, Romance, Thriller
# 581                          Mission       Comedy, Drama, Romance
# 578                              nan       Comedy, Drama, Romance
# 577                    Outer Mission       Comedy, Drama, Romance
# 580                   Bernal Heights       Comedy, Drama, Romance
# 828                         Seacliff       Drama, Mystery, Sci-Fi
# 584                       Noe Valley       Comedy, Drama, Romance
# 586                         Presidio       Comedy, Drama, Romance
# 837                      Mission Bay       Drama, Mystery, Sci-Fi
# 829                     Potrero Hill       Drama, Mystery, Sci-Fi
# 832                       Twin Peaks       Drama, Mystery, Sci-Fi
# 836                Lone Mountain/USF       Drama, Mystery, Sci-Fi
# 616                   Haight Ashbury       Comedy, Drama, Romance
# 615       Oceanview/Merced/Ingleside       Comedy, Drama, Romance
# 613                  Pacific Heights       Comedy, Drama, Romance
# 607                     Inner Sunset       Comedy, Drama, Romance
# 605                  Treasure Island       Comedy, Drama, Romance
# 590                       Tenderloin       Comedy, Drama, Romance
# 1271           Bayview Hunters Point             Biography, Drama
# 469                   Outer Richmond     Drama, Thriller, Western
# 1273                       Excelsior  Adventure, Biography, Drama
# 326                 Presidio Heights      Action, Crime, Thriller
# 1071              West of Twin Peaks     Drama, Mystery, Thriller
# 306                          Portola     Action, Adventure, Drama
# 1173                 Sunset/Parkside                        Drama
# 737                 Golden Gate Park               Drama, Romance
# 398                        Japantown    Comedy, Mystery, Thriller

# %% [markdown]
# ## Open AI- GPT3 generating movie summary

# %%
import os
import openai
from openai import OpenAI
with open('open_ai_api_key_project_v1.txt', 'r') as f:
    open_ai_key = f.read().strip()

# %%
model_name = 'gpt-4o-mini'

# %%
# Create a completion/chat
client = OpenAI(
    api_key=open_ai_key,  # This is the default and can be omitted
)
client

# %%
#create prompt response
movie_genre = "romantic comedy"
#tailor this to length of top movies in nhood,k as soeme have < 5 filmed in there
num_movies_to_use = 4
movie_inspo_list = ", ".join(["Ant-man", "Vertigo", "Pokemon Snap", "Dunkirk"])
movie_prompt=f"Write a 500 character plot summary of a fictional {movie_genre} genre movie, heavily inspired by the following media: {movie_inspo_list}. Incorporate elements from all stated medias."
print(movie_prompt)
# Out:
# Write a 500 character plot summary of a fictional romantic comedy genre movie, heavily inspired by the following media: Ant-man, Vertigo, Pokemon Snap, Dunkirk. Incorporate elements from all stated medias.

# %%
prompt_value = movie_prompt
response = client.chat.completions.create(
    model=model_name,  # or "gpt-4" or other models
   messages=[
        {"role": "developer", "content": "You are a helpful movie producer who is pitching a movie."},
        {"role": "user","content": prompt_value
        }
   ]
)

# Get the response
print(response.choices[0].message.content)
# Out:
# **Title: Love in Miniature**
#
# In a bustling city, aspiring photographer Mia discovers a mysterious camera that shrinks her subjects to ant-size. When she accidentally captures the charismatic but hapless inventor, Jack, in mini form, the two are thrown into a whirlwind of surreal adventures. As they navigate a vibrant urban landscape fraught with giant obstacles, classic enemies, and a quirky Pokémon Snap-like quest to capture the essence of love, they confront their pasts. Amid dizzying heights and comedic escapades, Mia and Jack must choose between returning to their normal lives or embracing a love that defies size.

# %%
text_output = response.choices[0].message.content
print(text_output)
#either 1- take most common genre
# or 2- take most popular/hioghly rated movies
# Out:
# **Title: Love in Miniature**
#
# In a bustling city, aspiring photographer Mia discovers a mysterious camera that shrinks her subjects to ant-size. When she accidentally captures the charismatic but hapless inventor, Jack, in mini form, the two are thrown into a whirlwind of surreal adventures. As they navigate a vibrant urban landscape fraught with giant obstacles, classic enemies, and a quirky Pokémon Snap-like quest to capture the essence of love, they confront their pasts. Amid dizzying heights and comedic escapades, Mia and Jack must choose between returning to their normal lives or embracing a love that defies size.

# %%
#ask to create poster based off of text output
poster_creation_prompt = f" Create a 500 character description of a movie poster to advertise the following movie, given its description: '{text_output}'. Include the title of the movie in the poster"
poster_creation_prompt
# Out:
# " Create a 500 character description of a movie poster to advertise the following movie, given its description: '**Title: Love in Miniature**\n\nIn a bustling city, aspiring photographer Mia discovers a mysterious camera that shrinks her subjects to ant-size. When she accidentally captures the charismatic but hapless inventor, Jack, in mini form, the two are thrown into a whirlwind of surreal adventures. As they navigate a vibrant urban landscape fraught with giant obstacles, classic enemies, and a quirky Pokémon Snap-like quest to capture the essence of love, they confront their pasts. Amid dizzying heights and comedic escapades, Mia and Jack must choose between returning to their normal lives or embracing a love that defies size.'. Include the title of the movie in the poster"

# %%
prompt_value = poster_creation_prompt
poster_response = client.chat.completions.create(
    model=model_name,  # or "gpt-4" or other models
   messages=[
        {"role": "developer", "content": "You are a graphic designer who is describing a movie poster."},
        {"role": "user","content": prompt_value
        }
   ]
)

# Get the response
print(poster_response.choices[0].message.content)
# Out:
# The movie poster for "**Love in Miniature**" bursts with vibrant colors, featuring a whimsical cityscape that looms large in the background. At the forefront, Mia, an aspiring photographer, is framed holding her peculiar, oversized camera, her eyes wide with wonder. A tiny Jack, the hapless inventor, stands at her feet, grinning up at her, encapsulating their unique bond. Giant plants and oversized objects surround them, hinting at their epic, miniature adventures. The title, **Love in Miniature**, arches playfully above them in a bold, stylized font, inviting viewers into a surreal world where love knows no size.

# %%
poster_description = poster_response.choices[0].message.content
poster_description
# Out:
# 'The movie poster for "**Love in Miniature**" bursts with vibrant colors, featuring a whimsical cityscape that looms large in the background. At the forefront, Mia, an aspiring photographer, is framed holding her peculiar, oversized camera, her eyes wide with wonder. A tiny Jack, the hapless inventor, stands at her feet, grinning up at her, encapsulating their unique bond. Giant plants and oversized objects surround them, hinting at their epic, miniature adventures. The title, **Love in Miniature**, arches playfully above them in a bold, stylized font, inviting viewers into a surreal world where love knows no size.'

# %% [markdown]
# ## Open AI- generate Dalle prompt

# %%
image_prompt = f" Make a movie poster for the following movie description: {poster_description}"
response = client.images.generate(
    model="dall-e-3",
    prompt=text_output,
    size="1024x1024",
    quality="standard",
    n=1,
)


print(response.data[0].url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-vbX8ft7z6vVlUWhtUB2ASm5I/user-AIdS0C9IeXYS9xoqHtkq6sSX/img-IwfTgYF8hTUa7qlJWGk6XT34.png?st=2025-01-20T02%3A41%3A09Z&se=2025-01-20T04%3A41%3A09Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-01-20T01%3A00%3A16Z&ske=2025-01-21T01%3A00%3A16Z&sks=b&skv=2024-08-04&sig=vZDTy3VI9Yd6UWcrDIUS0gQ/7e8rgg6mQZEIKGp0Hy0%3D
